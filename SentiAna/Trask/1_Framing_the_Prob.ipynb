# %% [markdown]
# ## Data Preparation

# %%
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Define path to the data
## Ubuntu path
path = "/home/isaac/UdacityDL/SentiAna/Trask/"
## Windows path
#path = "C:/UdacityDL/SentiAna/Trask/"

# %%
with open(path+"reviews.txt", "r+") as file:
    reviews = file.readlines() 
    ##use readlines as it will be separated by \n; read will read the whole thing as one big chunk of array
    file.close()

with open(path+"labels.txt", "r+") as file:
    labels = file.readlines()
    file.close()

# %%
reviews[0]
## Notice \n at the end of each review[i]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   \n'

# %%
labels[0]
## Notice \n at the end of each label[i]
# Out:
# 'positive\n'

# %%
reviews_clean = list(map(lambda x: x[:-1], reviews))
reviews_clean[0][:200]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  '

# %%
labels_clean = list(map(lambda x: x[:-1], labels))
labels_clean[0]
# Out:
# 'positive'

# %% [markdown]
# ## Quick Theory Validation

# %%
my_rand = np.random.randint(0,len(reviews_clean),10)
my_rand
# Out:
# array([15904,  4320,  6364, 23812, 17820, 24276, 13649, 18428,  9120, 24010])

# %%
for num in my_rand:
    print(labels_clean[num]+" : "+reviews_clean[num][:100]+"\n")
    print("-"*110)
# Out:
# positive : this is one of the most brilliant movies that i have seen in recent times . goes way above even any
#
# --------------------------------------------------------------------------------------------------------------
# positive : do you still love woody allen  s humor and sense of the absurd  do you wait patiently for movies tha
#
# --------------------------------------------------------------------------------------------------------------
# positive : there is nothing not to like about moonstruck . i  m from a new york italian family and i actually g
#
# --------------------------------------------------------------------------------------------------------------
# positive : i was drawn to dan in real life from the excellent reviews and the thirst for a dramedy that was wel
#
# --------------------------------------------------------------------------------------------------------------
# positive : airwolf the movie  a variation on the original  part pilot  yet the movie although shorter  does con
#
# --------------------------------------------------------------------------------------------------------------
# positive : the movie was very sweet and heartwarming  i cry almost every time i watch the movie . i would recom
#
# --------------------------------------------------------------------------------------------------------------
# negative : the movie is actually too slow . there are some nice images but it cannot outweigh the fact that the
#
# --------------------------------------------------------------------------------------------------------------
# positive : brand hauser  john cusack  is an assassin for the cia . he is ordered to go to the country of turaqu
#
# --------------------------------------------------------------------------------------------------------------
# positive : an entertaining and substantive film  non  stop has drawn deserving comparisons with  run lola run
#
# --------------------------------------------------------------------------------------------------------------
# positive : when our local tv station first launched  it filled a lot of its schedule with old british programmi
#
# --------------------------------------------------------------------------------------------------------------

# %%
## Initialization
positive_count = Counter()
negative_count = Counter()
total_count = Counter()

# %%
for i in range(len(reviews)):
    if(labels_clean[i] == "positive"):
        for word in reviews[i].split(" "):
            positive_count[word] += 1
            total_count[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_count[word] += 1
            total_count[word] += 1

# %%
positive_count.most_common()
# Out:
# [('', 537968),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('\n', 12500),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
#  ('some', 7441),
#  ('if', 7285),
#  ('just', 7152),
#  ('can', 7001),
#  ('story', 6780),
#  ('time', 6515),
#  ('my', 6488),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6321),
#  ('which', 6267),
#  ('their', 6107),
#  ('see', 6026),
#  ('also', 5550),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5218),
#  ('me', 5167),
#  ('had', 5148),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4864),
#  ('other', 4858),
#  ('were', 4782),
#  ('first', 4755),
#  ('than', 4736),
#  ('much', 4685),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4479),
#  ('best', 4319),
#  ('love', 4301),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4199),
#  ('been', 4189),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3941),
#  ('made', 3823),
#  ('films', 3813),
#  ('them', 3805),
#  ('after', 3800),
#  ('many', 3766),
#  ('two', 3733),
#  ('too', 3659),
#  ('think', 3655),
#  ('movies', 3586),
#  ('characters', 3560),
#  ('character', 3514),
#  ('don', 3468),
#  ('man', 3460),
#  ('show', 3432),
#  ('watch', 3424),
#  ('seen', 3414),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3303),
#  ('could', 3237),
#  ('never', 3226),
#  ('being', 3217),
#  ('where', 3173),
#  ('does', 3069),
#  ('over', 3017),
#  ('any', 3002),
#  ('while', 2899),
#  ('know', 2833),
#  ('did', 2790),
#  ('years', 2758),
#  ('here', 2740),
#  ('ever', 2734),
#  ('end', 2696),
#  ('these', 2694),
#  ('such', 2590),
#  ('real', 2568),
#  ('scene', 2567),
#  ('back', 2547),
#  ('those', 2485),
#  ('though', 2475),
#  ('off', 2463),
#  ('new', 2458),
#  ('your', 2453),
#  ('go', 2440),
#  ('acting', 2437),
#  ('plot', 2432),
#  ('world', 2429),
#  ('scenes', 2427),
#  ('say', 2414),
#  ('through', 2409),
#  ('makes', 2390),
#  ('better', 2381),
#  ('now', 2368),
#  ('work', 2346),
#  ('young', 2343),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2177),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2143),
#  ('something', 2135),
#  ('cast', 2133),
#  ('should', 2121),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('between', 2016),
#  ('own', 2016),
#  ('m', 1998),
#  ('may', 1997),
#  ('same', 1972),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1954),
#  ('funny', 1953),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1900),
#  ('re', 1884),
#  ('why', 1855),
#  ('things', 1849),
#  ('times', 1832),
#  ('big', 1815),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1783),
#  ('bit', 1757),
#  ('comedy', 1742),
#  ('down', 1740),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1709),
#  ('saw', 1692),
#  ('long', 1690),
#  ('right', 1688),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('didn', 1672),
#  ('without', 1671),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1635),
#  ('each', 1630),
#  ('day', 1614),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1553),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1490),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1447),
#  ('horror', 1441),
#  ('woman', 1439),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1378),
#  ('wonderful', 1372),
#  ('far', 1358),
#  ('course', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1328),
#  ('ll', 1326),
#  ('dvd', 1324),
#  ('later', 1324),
#  ('war', 1310),
#  ('whole', 1310),
#  ('d', 1307),
#  ('away', 1306),
#  ('found', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('year', 1297),
#  ('once', 1296),
#  ('hard', 1294),
#  ('together', 1280),
#  ('am', 1277),
#  ('set', 1277),
#  ('having', 1266),
#  ('making', 1265),
#  ('place', 1263),
#  ('might', 1260),
#  ('comes', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('perfect', 1242),
#  ('takes', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('everyone', 1221),
#  ('worth', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1201),
#  ('wife', 1196),
#  ('classic', 1192),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1128),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1095),
#  ('watched', 1094),
#  ('loved', 1087),
#  ('men', 1087),
#  ('night', 1082),
#  ('anything', 1075),
#  ('believe', 1071),
#  ('guy', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('gives', 1031),
#  ('home', 1029),
#  ('seem', 1028),
#  ('episode', 1023),
#  ('audience', 1020),
#  ('sense', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('short', 1009),
#  ('second', 1009),
#  ('fan', 1009),
#  ('mind', 1005),
#  ('human', 1001),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 991),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 970),
#  ('said', 966),
#  ('favorite', 962),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 955),
#  ('script', 954),
#  ('let', 954),
#  ('maybe', 937),
#  ('today', 936),
#  ('less', 934),
#  ('live', 934),
#  ('moments', 933),
#  ('others', 929),
#  ('brilliant', 926),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 910),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 890),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('highly', 871),
#  ('given', 870),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 859),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 854),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 850),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('keep', 831),
#  ('face', 831),
#  ('friend', 831),
#  ('dark', 830),
#  ('overall', 828),
#  ('certainly', 828),
#  ('minutes', 827),
#  ('wasn', 824),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('understand', 808),
#  ('lost', 807),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('written', 787),
#  ('production', 787),
#  ('several', 784),
#  ('school', 783),
#  ('rest', 781),
#  ('based', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('past', 744),
#  ('start', 744),
#  ('genre', 743),
#  ('final', 739),
#  ('beginning', 739),
#  ('town', 738),
#  ('art', 734),
#  ('humor', 732),
#  ('game', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('despite', 729),
#  ('becomes', 729),
#  ('case', 726),
#  ('able', 726),
#  ('money', 723),
#  ('child', 721),
#  ('completely', 721),
#  ('side', 719),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 712),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 697),
#  ('days', 696),
#  ('stories', 696),
#  ('simple', 694),
#  ('felt', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('either', 683),
#  ('name', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('wants', 671),
#  ('close', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('budget', 657),
#  ('episodes', 657),
#  ('relationship', 655),
#  ('fantastic', 653),
#  ('piece', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('head', 643),
#  ('absolutely', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('called', 637),
#  ('direction', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 630),
#  ('oscar', 628),
#  ('including', 627),
#  ('example', 627),
#  ('musical', 625),
#  ('known', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('already', 619),
#  ('hit', 619),
#  ('feeling', 619),
#  ('voice', 615),
#  ('moment', 612),
#  ('living', 612),
#  ('supporting', 610),
#  ('low', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('hilarious', 605),
#  ('reality', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 601),
#  ('dialogue', 600),
#  ('quality', 600),
#  ('moving', 600),
#  ('song', 599),
#  ('happy', 599),
#  ('paul', 598),
#  ('matter', 598),
#  ('light', 594),
#  ('future', 593),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 584),
#  ('fight', 581),
#  ('particularly', 580),
#  ('police', 579),
#  ('cinematography', 579),
#  ('type', 578),
#  ('whose', 578),
#  ('sound', 578),
#  ('enjoyable', 573),
#  ('view', 573),
#  ('husband', 572),
#  ('number', 572),
#  ('daughter', 572),
#  ('romantic', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('modern', 569),
#  ('took', 569),
#  ('robert', 569),
#  ('superb', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('leave', 559),
#  ('king', 559),
#  ('change', 558),
#  ('wanted', 555),
#  ('somewhat', 555),
#  ('tells', 554),
#  ('country', 552),
#  ('career', 552),
#  ('events', 552),
#  ('run', 552),
#  ('season', 550),
#  ('heard', 550),
#  ('girls', 549),
#  ('greatest', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('animation', 540),
#  ('tale', 540),
#  ('totally', 540),
#  ('guys', 540),
#  ('usual', 539),
#  ('miss', 535),
#  ('opinion', 535),
#  ('easy', 531),
#  ('violence', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 526),
#  ('realistic', 525),
#  ('writing', 524),
#  ('writer', 522),
#  ('act', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('novel', 513),
#  ('york', 513),
#  ('alone', 512),
#  ('problem', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('kill', 507),
#  ('extremely', 507),
#  ('seemed', 506),
#  ('hero', 505),
#  ('french', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('similar', 491),
#  ('taking', 491),
#  ('surprised', 491),
#  ('car', 491),
#  ('george', 490),
#  ('perfectly', 490),
#  ('team', 489),
#  ('across', 489),
#  ('sequence', 489),
#  ('eye', 489),
#  ('due', 488),
#  ('powerful', 488),
#  ('serious', 488),
#  ('room', 488),
#  ('among', 488),
#  ('b', 487),
#  ('order', 487),
#  ('strange', 487),
#  ('cannot', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('happened', 484),
#  ('herself', 484),
#  ('myself', 484),
#  ('tries', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('release', 479),
#  ('theme', 479),
#  ('anyway', 479),
#  ('opening', 478),
#  ('entertainment', 477),
#  ('slow', 475),
#  ('exactly', 475),
#  ('unique', 475),
#  ('ends', 475),
#  ('level', 474),
#  ('easily', 474),
#  ('o', 474),
#  ('red', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('viewing', 468),
#  ('memorable', 467),
#  ('sets', 467),
#  ('group', 466),
#  ('stop', 466),
#  ('message', 463),
#  ('problems', 463),
#  ('dance', 463),
#  ('working', 463),
#  ('sister', 463),
#  ('knew', 462),
#  ('nature', 461),
#  ('mystery', 461),
#  ('bring', 460),
#  ('brought', 459),
#  ('thinking', 459),
#  ('believable', 459),
#  ('mostly', 458),
#  ('couldn', 457),
#  ('disney', 457),
#  ('society', 456),
#  ('lady', 455),
#  ('within', 455),
#  ('blood', 454),
#  ('upon', 453),
#  ('viewers', 453),
#  ('parents', 453),
#  ('usually', 452),
#  ('soundtrack', 452),
#  ('meets', 452),
#  ('tom', 452),
#  ('peter', 452),
#  ('form', 452),
#  ('local', 450),
#  ('certain', 448),
#  ('follow', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('emotional', 445),
#  ('killed', 444),
#  ('above', 444),
#  ('de', 444),
#  ('god', 443),
#  ('middle', 443),
#  ('happens', 442),
#  ('flick', 442),
#  ('needs', 442),
#  ('masterpiece', 441),
#  ('period', 440),
#  ('major', 440),
#  ('named', 439),
#  ('haven', 439),
#  ('th', 438),
#  ('particular', 438),
#  ('earth', 437),
#  ('feature', 437),
#  ('stand', 436),
#  ('words', 435),
#  ('typical', 435),
#  ('obviously', 433),
#  ('elements', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('showing', 427),
#  ('yourself', 427),
#  ('fantasy', 426),
#  ('brings', 426),
#  ('america', 423),
#  ('guess', 423),
#  ('huge', 422),
#  ('unfortunately', 422),
#  ('running', 421),
#  ('indeed', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('sweet', 417),
#  ('leads', 417),
#  ('japanese', 417),
#  ('deal', 416),
#  ('poor', 416),
#  ('personal', 413),
#  ('incredible', 413),
#  ('fast', 412),
#  ('became', 410),
#  ('deep', 410),
#  ('hours', 409),
#  ('dream', 408),
#  ('nearly', 408),
#  ('giving', 408),
#  ('clearly', 407),
#  ('turned', 407),
#  ('obvious', 406),
#  ('near', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('body', 404),
#  ('era', 404),
#  ('female', 403),
#  ('five', 403),
#  ('hour', 403),
#  ('note', 399),
#  ('learn', 398),
#  ('truth', 398),
#  ('except', 397),
#  ('match', 397),
#  ('feels', 397),
#  ('tony', 397),
#  ('filmed', 394),
#  ('complete', 394),
#  ('clear', 394),
#  ('keeps', 393),
#  ('eventually', 393),
#  ('lots', 393),
#  ('street', 393),
#  ('older', 393),
#  ('buy', 392),
#  ('stewart', 391),
#  ('william', 391),
#  ('joe', 390),
#  ('fall', 390),
#  ('meet', 390),
#  ('rating', 389),
#  ('unlike', 389),
#  ('talking', 389),
#  ('shots', 389),
#  ('difficult', 389),
#  ('dramatic', 388),
#  ('means', 388),
#  ('present', 386),
#  ('wonder', 386),
#  ('appears', 386),
#  ('situation', 386),
#  ('subject', 386),
#  ('comments', 385),
#  ('sequences', 383),
#  ('lee', 383),
#  ('general', 383),
#  ('earlier', 382),
#  ('points', 382),
#  ('check', 379),
#  ('gone', 379),
#  ('recommended', 378),
#  ('ten', 378),
#  ('suspense', 378),
#  ('business', 377),
#  ('third', 377),
#  ('beyond', 375),
#  ('leaves', 375),
#  ('talk', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('bill', 372),
#  ('single', 372),
#  ('plenty', 371),
#  ('word', 371),
#  ('falls', 370),
#  ('whom', 370),
#  ('figure', 369),
#  ('non', 369),
#  ('scary', 369),
#  ('battle', 369),
#  ('using', 368),
#  ('return', 368),
#  ('add', 367),
#  ('doubt', 367),
#  ('hear', 366),
#  ('success', 366),
#  ('solid', 366),
#  ('political', 365),
#  ('oh', 365),
#  ('touching', 365),
#  ('jokes', 365),
#  ('awesome', 364),
#  ('hell', 364),
#  ('boys', 364),
#  ('recently', 362),
#  ('dog', 362),
#  ('sexual', 362),
#  ('straight', 361),
#  ('wouldn', 361),
#  ('features', 361),
#  ('please', 361),
#  ('lack', 360),
#  ('setting', 360),
#  ('forget', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('interested', 356),
#  ('adventure', 356),
#  ('actual', 355),
#  ('terrific', 355),
#  ('sees', 355),
#  ('brothers', 355),
#  ('call', 354),
#  ('move', 354),
#  ('various', 353),
#  ('dr', 353),
#  ('theater', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('space', 350),
#  ('baby', 350),
#  ('leading', 348),
#  ('disappointed', 348),
#  ('portrayed', 346),
#  ('aren', 346),
#  ('smith', 345),
#  ('screenplay', 345),
#  ('hate', 344),
#  ('towards', 344),
#  ('noir', 343),
#  ('kelly', 342),
#  ('decent', 342),
#  ('outstanding', 342),
#  ('journey', 341),
#  ('directors', 341),
#  ('none', 340),
#  ('effective', 340),
#  ('looked', 340),
#  ('sci', 339),
#  ('mary', 339),
#  ('storyline', 339),
#  ('fi', 339),
#  ('cold', 339),
#  ('caught', 339),
#  ('rich', 338),
#  ('charming', 338),
#  ('popular', 337),
#  ('manages', 337),
#  ('harry', 337),
#  ('rare', 337),
#  ('spirit', 336),
#  ('open', 335),
#  ('appreciate', 335),
#  ('acted', 334),
#  ('moves', 334),
#  ('basically', 334),
#  ('pace', 333),
#  ('mention', 333),
#  ('subtle', 333),
#  ('inside', 333),
#  ('boring', 333),
#  ('deserves', 333),
#  ('century', 333),
#  ('familiar', 332),
#  ('background', 332),
#  ('ben', 331),
#  ('creepy', 330),
#  ('supposed', 330),
#  ('secret', 329),
#  ('die', 328),
#  ('jim', 328),
#  ('effect', 327),
#  ('natural', 327),
#  ('question', 327),
#  ('language', 326),
#  ('rate', 326),
#  ('impressive', 326),
#  ('saying', 325),
#  ('intelligent', 325),
#  ('telling', 324),
#  ('scott', 324),
#  ('realize', 324),
#  ('material', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('adult', 321),
#  ('visual', 321),
#  ('imagine', 321),
#  ('office', 320),
#  ('kept', 320),
#  ('uses', 319),
#  ('pure', 318),
#  ('stunning', 318),
#  ('wait', 318),
#  ('copy', 317),
#  ('previous', 317),
#  ('seriously', 317),
#  ('review', 317),
#  ('created', 316),
#  ('somehow', 316),
#  ('magic', 316),
#  ('reading', 316),
#  ('create', 316),
#  ('hot', 316),
#  ('frank', 315),
#  ('crazy', 315),
#  ('escape', 315),
#  ('air', 315),
#  ('attempt', 315),
#  ('stay', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('surprisingly', 312),
#  ('average', 312),
#  ('expected', 312),
#  ('complex', 311),
#  ('studio', 310),
#  ('quickly', 310),
#  ('successful', 310),
#  ('male', 309),
#  ('plus', 309),
#  ('co', 307),
#  ('images', 306),
#  ('minute', 306),
#  ('exciting', 306),
#  ('casting', 306),
#  ('following', 306),
#  ('themes', 305),
#  ('reasons', 305),
#  ('e', 305),
#  ('members', 305),
#  ('german', 305),
#  ('follows', 305),
#  ('touch', 304),
#  ('edge', 304),
#  ('free', 304),
#  ('genius', 304),
#  ('cute', 304),
#  ('outside', 303),
#  ('admit', 302),
#  ('reviews', 302),
#  ('younger', 302),
#  ('ok', 302),
#  ('master', 301),
#  ('odd', 301),
#  ('fighting', 301),
#  ('comment', 300),
#  ('break', 300),
#  ('thanks', 300),
#  ('recent', 300),
#  ('apart', 299),
#  ('emotions', 298),
#  ('begin', 298),
#  ('lovely', 298),
#  ('party', 297),
#  ('italian', 297),
#  ('doctor', 297),
#  ('clever', 296),
#  ...]

# %%
negative_count.most_common()
# Out:
# [('', 548962),
#  ('.', 167538),
#  ('the', 163389),
#  ('a', 79321),
#  ('and', 74385),
#  ('of', 69009),
#  ('to', 68974),
#  ('br', 52637),
#  ('is', 50083),
#  ('it', 48327),
#  ('i', 46880),
#  ('in', 43753),
#  ('this', 40920),
#  ('that', 37615),
#  ('s', 31546),
#  ('was', 26291),
#  ('movie', 24965),
#  ('for', 21927),
#  ('but', 21781),
#  ('with', 20878),
#  ('as', 20625),
#  ('t', 20361),
#  ('film', 19218),
#  ('you', 17549),
#  ('on', 17192),
#  ('not', 16354),
#  ('have', 15144),
#  ('are', 14623),
#  ('be', 14541),
#  ('he', 13856),
#  ('one', 13134),
#  ('they', 13011),
#  ('\n', 12500),
#  ('at', 12279),
#  ('his', 12147),
#  ('all', 12036),
#  ('so', 11463),
#  ('like', 11238),
#  ('there', 10775),
#  ('just', 10619),
#  ('by', 10549),
#  ('or', 10272),
#  ('an', 10266),
#  ('who', 9969),
#  ('from', 9731),
#  ('if', 9518),
#  ('about', 9061),
#  ('out', 8979),
#  ('what', 8422),
#  ('some', 8306),
#  ('no', 8143),
#  ('her', 7947),
#  ('even', 7687),
#  ('can', 7653),
#  ('has', 7604),
#  ('good', 7423),
#  ('bad', 7401),
#  ('would', 7036),
#  ('up', 6970),
#  ('only', 6781),
#  ('more', 6730),
#  ('when', 6726),
#  ('she', 6444),
#  ('really', 6262),
#  ('time', 6209),
#  ('had', 6142),
#  ('my', 6015),
#  ('were', 6001),
#  ('which', 5780),
#  ('very', 5764),
#  ('me', 5606),
#  ('see', 5452),
#  ('don', 5336),
#  ('we', 5328),
#  ('their', 5278),
#  ('do', 5236),
#  ('story', 5208),
#  ('than', 5183),
#  ('been', 5100),
#  ('much', 5078),
#  ('get', 5037),
#  ('because', 4966),
#  ('people', 4806),
#  ('then', 4761),
#  ('make', 4722),
#  ('how', 4688),
#  ('could', 4686),
#  ('any', 4658),
#  ('into', 4567),
#  ('made', 4541),
#  ('first', 4306),
#  ('other', 4305),
#  ('well', 4254),
#  ('too', 4174),
#  ('them', 4165),
#  ('plot', 4154),
#  ('movies', 4080),
#  ('acting', 4056),
#  ('will', 3993),
#  ('way', 3989),
#  ('most', 3919),
#  ('him', 3858),
#  ('after', 3838),
#  ('its', 3655),
#  ('think', 3643),
#  ('also', 3608),
#  ('characters', 3600),
#  ('off', 3567),
#  ('watch', 3550),
#  ('did', 3506),
#  ('character', 3506),
#  ('why', 3463),
#  ('being', 3393),
#  ('better', 3358),
#  ('know', 3334),
#  ('over', 3316),
#  ('seen', 3265),
#  ('ever', 3263),
#  ('never', 3259),
#  ('your', 3233),
#  ('where', 3219),
#  ('two', 3173),
#  ('little', 3096),
#  ('films', 3077),
#  ('here', 3027),
#  ('m', 3000),
#  ('nothing', 2990),
#  ('say', 2982),
#  ('end', 2954),
#  ('something', 2942),
#  ('should', 2920),
#  ('many', 2909),
#  ('does', 2871),
#  ('thing', 2866),
#  ('show', 2862),
#  ('ve', 2829),
#  ('scene', 2816),
#  ('scenes', 2785),
#  ('these', 2724),
#  ('go', 2717),
#  ('didn', 2646),
#  ('watching', 2640),
#  ('great', 2640),
#  ('re', 2620),
#  ('doesn', 2601),
#  ('through', 2560),
#  ('such', 2544),
#  ('man', 2516),
#  ('worst', 2480),
#  ('actually', 2449),
#  ('actors', 2437),
#  ('life', 2429),
#  ('back', 2424),
#  ('while', 2418),
#  ('director', 2405),
#  ('funny', 2336),
#  ('going', 2319),
#  ('still', 2283),
#  ('another', 2254),
#  ('look', 2247),
#  ('now', 2237),
#  ('old', 2215),
#  ('those', 2212),
#  ('real', 2170),
#  ('few', 2158),
#  ('love', 2152),
#  ('horror', 2150),
#  ('before', 2147),
#  ('want', 2141),
#  ('minutes', 2126),
#  ('pretty', 2115),
#  ('best', 2094),
#  ('though', 2091),
#  ('same', 2081),
#  ('script', 2074),
#  ('work', 2027),
#  ('every', 2025),
#  ('seems', 2023),
#  ('least', 2011),
#  ('enough', 1997),
#  ('down', 1988),
#  ('original', 1983),
#  ('guy', 1964),
#  ('got', 1952),
#  ('around', 1943),
#  ('part', 1942),
#  ('lot', 1892),
#  ('anything', 1874),
#  ('find', 1860),
#  ('new', 1854),
#  ('isn', 1849),
#  ('again', 1849),
#  ('point', 1845),
#  ('fact', 1839),
#  ('things', 1839),
#  ('give', 1823),
#  ('makes', 1814),
#  ('take', 1800),
#  ('thought', 1798),
#  ('d', 1770),
#  ('whole', 1768),
#  ('long', 1761),
#  ('years', 1759),
#  ('however', 1740),
#  ('gets', 1714),
#  ('making', 1695),
#  ('cast', 1694),
#  ('big', 1662),
#  ('might', 1658),
#  ('interesting', 1648),
#  ('money', 1638),
#  ('us', 1628),
#  ('right', 1625),
#  ('far', 1619),
#  ('quite', 1596),
#  ('come', 1595),
#  ('without', 1595),
#  ('almost', 1574),
#  ('ll', 1567),
#  ('action', 1566),
#  ('awful', 1557),
#  ('kind', 1539),
#  ('reason', 1534),
#  ('am', 1530),
#  ('looks', 1528),
#  ('must', 1522),
#  ('done', 1510),
#  ('comedy', 1504),
#  ('someone', 1490),
#  ('trying', 1486),
#  ('wasn', 1484),
#  ('poor', 1481),
#  ('instead', 1478),
#  ('boring', 1478),
#  ('saw', 1475),
#  ('away', 1469),
#  ('girl', 1463),
#  ('probably', 1444),
#  ('believe', 1434),
#  ('sure', 1433),
#  ('looking', 1430),
#  ('stupid', 1428),
#  ('anyone', 1418),
#  ('times', 1406),
#  ('maybe', 1404),
#  ('world', 1404),
#  ('rather', 1394),
#  ('terrible', 1391),
#  ('may', 1390),
#  ('last', 1390),
#  ('since', 1388),
#  ('let', 1385),
#  ('tv', 1382),
#  ('between', 1374),
#  ('hard', 1374),
#  ('waste', 1358),
#  ('woman', 1356),
#  ('feel', 1354),
#  ('effects', 1348),
#  ('half', 1341),
#  ('own', 1333),
#  ('young', 1317),
#  ('music', 1316),
#  ('idea', 1312),
#  ('sense', 1306),
#  ('bit', 1298),
#  ('having', 1280),
#  ('book', 1278),
#  ('found', 1267),
#  ('series', 1263),
#  ('put', 1263),
#  ('goes', 1256),
#  ('worse', 1249),
#  ('said', 1230),
#  ('comes', 1224),
#  ('role', 1222),
#  ('main', 1220),
#  ('else', 1199),
#  ('everything', 1197),
#  ('yet', 1196),
#  ('low', 1189),
#  ('screen', 1188),
#  ('supposed', 1186),
#  ('actor', 1185),
#  ('either', 1183),
#  ('ending', 1179),
#  ('budget', 1179),
#  ('audience', 1178),
#  ('set', 1177),
#  ('family', 1170),
#  ('left', 1169),
#  ('completely', 1168),
#  ('both', 1158),
#  ('wrong', 1155),
#  ('always', 1151),
#  ('place', 1148),
#  ('course', 1148),
#  ('seem', 1147),
#  ('watched', 1142),
#  ('day', 1132),
#  ('simply', 1130),
#  ('shot', 1126),
#  ('mean', 1117),
#  ('special', 1102),
#  ('dead', 1101),
#  ('three', 1094),
#  ('house', 1085),
#  ('oh', 1084),
#  ('night', 1083),
#  ('read', 1082),
#  ('less', 1067),
#  ('high', 1066),
#  ('year', 1064),
#  ('camera', 1061),
#  ('worth', 1057),
#  ('our', 1056),
#  ('try', 1051),
#  ('horrible', 1046),
#  ('sex', 1046),
#  ('video', 1043),
#  ('black', 1039),
#  ('couldn', 1036),
#  ('although', 1036),
#  ('once', 1033),
#  ('rest', 1022),
#  ('dvd', 1021),
#  ('line', 1018),
#  ('played', 1017),
#  ('fun', 1007),
#  ('during', 1006),
#  ('production', 1003),
#  ('everyone', 1002),
#  ('play', 993),
#  ('mind', 990),
#  ('version', 989),
#  ('kids', 989),
#  ('seeing', 988),
#  ('american', 980),
#  ('given', 978),
#  ('used', 969),
#  ('performance', 968),
#  ('together', 963),
#  ('especially', 963),
#  ('tell', 959),
#  ('women', 958),
#  ('start', 956),
#  ('need', 955),
#  ('second', 953),
#  ('takes', 950),
#  ('each', 950),
#  ('wife', 944),
#  ('dialogue', 942),
#  ('use', 940),
#  ('problem', 938),
#  ('star', 934),
#  ('unfortunately', 931),
#  ('himself', 929),
#  ('doing', 926),
#  ('death', 922),
#  ('name', 921),
#  ('lines', 919),
#  ('killer', 914),
#  ('getting', 913),
#  ('help', 905),
#  ('fan', 902),
#  ('couple', 902),
#  ('head', 898),
#  ('crap', 895),
#  ('guess', 888),
#  ('piece', 884),
#  ('nice', 880),
#  ('different', 878),
#  ('school', 876),
#  ('later', 875),
#  ('entire', 869),
#  ('shows', 860),
#  ('next', 858),
#  ('john', 858),
#  ('seemed', 857),
#  ('short', 857),
#  ('hollywood', 850),
#  ('home', 848),
#  ('true', 846),
#  ('person', 846),
#  ('absolutely', 842),
#  ('sort', 840),
#  ('care', 839),
#  ('understand', 836),
#  ('plays', 835),
#  ('felt', 834),
#  ('written', 829),
#  ('title', 828),
#  ('men', 822),
#  ('until', 821),
#  ('flick', 816),
#  ('decent', 815),
#  ('face', 814),
#  ('friends', 810),
#  ('case', 807),
#  ('stars', 807),
#  ('job', 807),
#  ('itself', 804),
#  ('yes', 801),
#  ('perhaps', 800),
#  ('wanted', 797),
#  ('went', 797),
#  ('called', 796),
#  ('annoying', 795),
#  ('tries', 790),
#  ('ridiculous', 790),
#  ('laugh', 788),
#  ('evil', 787),
#  ('along', 786),
#  ('top', 785),
#  ('hour', 784),
#  ('full', 783),
#  ('came', 780),
#  ('writing', 780),
#  ('keep', 770),
#  ('totally', 767),
#  ('playing', 766),
#  ('god', 765),
#  ('won', 764),
#  ('guys', 763),
#  ('already', 762),
#  ('gore', 757),
#  ('direction', 748),
#  ('save', 746),
#  ('lost', 745),
#  ('example', 744),
#  ('sound', 742),
#  ('war', 741),
#  ('attempt', 735),
#  ('except', 733),
#  ('car', 733),
#  ('blood', 732),
#  ('moments', 732),
#  ('obviously', 730),
#  ('act', 729),
#  ('remember', 728),
#  ('kill', 727),
#  ('truly', 726),
#  ('white', 726),
#  ('father', 726),
#  ('b', 725),
#  ('thinking', 720),
#  ('finally', 716),
#  ('ok', 716),
#  ('turn', 711),
#  ('quality', 701),
#  ('lack', 698),
#  ('style', 694),
#  ('wouldn', 693),
#  ('cheap', 691),
#  ('none', 690),
#  ('kid', 686),
#  ('please', 686),
#  ('boy', 685),
#  ('seriously', 684),
#  ('lead', 680),
#  ('dull', 677),
#  ('children', 676),
#  ('starts', 675),
#  ('stuff', 673),
#  ('hope', 672),
#  ('looked', 670),
#  ('recommend', 669),
#  ('under', 668),
#  ('killed', 667),
#  ('run', 667),
#  ('enjoy', 666),
#  ('others', 666),
#  ('etc', 663),
#  ('myself', 663),
#  ('girls', 662),
#  ('beginning', 662),
#  ('against', 662),
#  ('obvious', 660),
#  ('small', 660),
#  ('hell', 659),
#  ('slow', 657),
#  ('hand', 656),
#  ('lame', 652),
#  ('wonder', 652),
#  ('picture', 651),
#  ('becomes', 651),
#  ('based', 650),
#  ('early', 648),
#  ('behind', 646),
#  ('poorly', 644),
#  ('avoid', 642),
#  ('complete', 640),
#  ('apparently', 640),
#  ('happens', 639),
#  ('anyway', 638),
#  ('classic', 637),
#  ('several', 636),
#  ('despite', 635),
#  ('episode', 635),
#  ('certainly', 635),
#  ('often', 631),
#  ('writer', 630),
#  ('cut', 630),
#  ('mother', 628),
#  ('predictable', 628),
#  ('gave', 628),
#  ('become', 627),
#  ('close', 625),
#  ('fans', 624),
#  ('saying', 621),
#  ('scary', 619),
#  ('live', 618),
#  ('stop', 618),
#  ('wants', 617),
#  ('self', 615),
#  ('mr', 612),
#  ('jokes', 611),
#  ('friend', 611),
#  ('cannot', 610),
#  ('overall', 609),
#  ('cinema', 604),
#  ('child', 603),
#  ('silly', 601),
#  ('beautiful', 596),
#  ('human', 595),
#  ('expect', 594),
#  ('liked', 593),
#  ('happened', 592),
#  ('entertaining', 590),
#  ('bunch', 590),
#  ('actress', 588),
#  ('final', 588),
#  ('says', 584),
#  ('performances', 584),
#  ('turns', 577),
#  ('humor', 577),
#  ('themselves', 576),
#  ('eyes', 576),
#  ('hours', 574),
#  ('happen', 573),
#  ('basically', 572),
#  ('days', 572),
#  ('running', 571),
#  ('call', 569),
#  ('involved', 569),
#  ('disappointed', 569),
#  ('directed', 568),
#  ('group', 568),
#  ('fight', 567),
#  ('talking', 566),
#  ('body', 566),
#  ('daughter', 566),
#  ('sorry', 565),
#  ('badly', 565),
#  ('throughout', 563),
#  ('viewer', 563),
#  ('extremely', 562),
#  ('yourself', 562),
#  ('interest', 561),
#  ('heard', 561),
#  ('violence', 561),
#  ('shots', 559),
#  ('side', 557),
#  ('word', 556),
#  ('art', 555),
#  ('possible', 554),
#  ('dark', 551),
#  ('game', 551),
#  ('hero', 550),
#  ('alone', 549),
#  ('son', 547),
#  ('type', 547),
#  ('leave', 547),
#  ('single', 546),
#  ('gives', 546),
#  ('parts', 546),
#  ('started', 545),
#  ('female', 543),
#  ('rating', 541),
#  ('voice', 541),
#  ('mess', 541),
#  ('town', 540),
#  ('aren', 540),
#  ('drama', 538),
#  ('definitely', 537),
#  ('unless', 536),
#  ('review', 534),
#  ('weak', 533),
#  ('able', 533),
#  ('effort', 533),
#  ('took', 531),
#  ('non', 530),
#  ('five', 530),
#  ('usually', 529),
#  ('matter', 529),
#  ('michael', 528),
#  ('feeling', 526),
#  ('huge', 523),
#  ('sequel', 522),
#  ('soon', 521),
#  ('exactly', 520),
#  ('past', 519),
#  ('police', 518),
#  ('turned', 518),
#  ('tried', 515),
#  ('middle', 513),
#  ('talent', 513),
#  ('genre', 512),
#  ('zombie', 510),
#  ('ends', 509),
#  ('history', 509),
#  ('straight', 503),
#  ('serious', 501),
#  ('opening', 501),
#  ('coming', 501),
#  ('moment', 500),
#  ('sad', 499),
#  ('lives', 499),
#  ('dialog', 498),
#  ('particularly', 498),
#  ('editing', 493),
#  ('clearly', 492),
#  ('beyond', 491),
#  ('earth', 491),
#  ('taken', 490),
#  ('cool', 490),
#  ('level', 489),
#  ('dumb', 489),
#  ('okay', 488),
#  ('major', 487),
#  ('fast', 485),
#  ('premise', 485),
#  ('joke', 484),
#  ('stories', 484),
#  ('wasted', 483),
#  ('minute', 483),
#  ('mostly', 482),
#  ('across', 482),
#  ('rent', 482),
#  ('fails', 481),
#  ('late', 481),
#  ('falls', 481),
#  ('mention', 478),
#  ('theater', 475),
#  ('stay', 472),
#  ('sometimes', 472),
#  ('hit', 468),
#  ('fine', 467),
#  ('talk', 467),
#  ('die', 466),
#  ('storyline', 465),
#  ('pointless', 465),
#  ('taking', 464),
#  ('order', 462),
#  ('brother', 461),
#  ('told', 460),
#  ('whatever', 460),
#  ('wish', 458),
#  ('room', 456),
#  ('write', 455),
#  ('career', 455),
#  ('appears', 455),
#  ('husband', 454),
#  ('known', 454),
#  ('living', 451),
#  ('sit', 450),
#  ('ten', 450),
#  ('words', 449),
#  ('chance', 448),
#  ('monster', 448),
#  ('novel', 444),
#  ('hate', 444),
#  ('add', 443),
#  ('english', 443),
#  ('somehow', 441),
#  ('strange', 440),
#  ('imdb', 438),
#  ('actual', 438),
#  ('ones', 437),
#  ('killing', 437),
#  ('total', 437),
#  ('material', 437),
#  ('knew', 436),
#  ('number', 434),
#  ('king', 434),
#  ('using', 433),
#  ('lee', 431),
#  ('giving', 431),
#  ('power', 431),
#  ('works', 431),
#  ('shown', 431),
#  ('kept', 430),
#  ('possibly', 430),
#  ('points', 430),
#  ('four', 429),
#  ('local', 427),
#  ('usual', 426),
#  ('including', 425),
#  ('problems', 424),
#  ('opinion', 424),
#  ('ago', 424),
#  ('nudity', 423),
#  ('age', 422),
#  ('due', 421),
#  ('roles', 420),
#  ('decided', 419),
#  ('writers', 419),
#  ('easily', 418),
#  ('flat', 418),
#  ('near', 418),
#  ('experience', 417),
#  ('murder', 417),
#  ('reviews', 416),
#  ('imagine', 415),
#  ('feels', 413),
#  ('somewhat', 411),
#  ('plain', 411),
#  ('score', 410),
#  ('class', 410),
#  ('whether', 409),
#  ('bring', 409),
#  ('song', 409),
#  ('otherwise', 408),
#  ('average', 408),
#  ('whose', 408),
#  ('nearly', 407),
#  ('pathetic', 407),
#  ('zombies', 407),
#  ('knows', 407),
#  ('upon', 406),
#  ('cinematography', 406),
#  ('cheesy', 406),
#  ('city', 405),
#  ('space', 405),
#  ('credits', 404),
#  ('james', 403),
#  ('change', 403),
#  ('lots', 403),
#  ('nor', 402),
#  ('entertainment', 402),
#  ('wait', 401),
#  ('released', 400),
#  ('needs', 399),
#  ('shame', 398),
#  ('attention', 396),
#  ('comments', 394),
#  ('bored', 393),
#  ('free', 393),
#  ('lady', 393),
#  ('expected', 392),
#  ('needed', 392),
#  ('clear', 392),
#  ('view', 391),
#  ('check', 390),
#  ('development', 390),
#  ('doubt', 390),
#  ('figure', 389),
#  ('mystery', 389),
#  ('garbage', 388),
#  ('excellent', 388),
#  ('television', 386),
#  ('sequence', 386),
#  ('o', 385),
#  ('sets', 385),
#  ('potential', 384),
#  ('laughable', 384),
#  ('documentary', 382),
#  ('reality', 382),
#  ('robert', 382),
#  ('country', 382),
#  ('light', 382),
#  ('ask', 381),
#  ('general', 381),
#  ('begin', 380),
#  ('fall', 380),
#  ('comic', 380),
#  ('forced', 379),
#  ('trash', 379),
#  ('footage', 379),
#  ('remake', 379),
#  ('stand', 379),
#  ('thriller', 378),
#  ('songs', 378),
#  ('gay', 377),
#  ('within', 377),
#  ('hardly', 376),
#  ('gone', 375),
#  ('above', 375),
#  ('george', 374),
#  ('means', 373),
#  ('sounds', 373),
#  ('buy', 372),
#  ('directing', 372),
#  ('move', 372),
#  ('david', 372),
#  ('rock', 371),
#  ('forward', 371),
#  ('important', 371),
#  ('filmed', 370),
#  ('haven', 370),
#  ('british', 370),
#  ('hot', 370),
#  ('heart', 369),
#  ('fake', 369),
#  ('reading', 369),
#  ('weird', 368),
#  ('incredibly', 368),
#  ('hear', 368),
#  ('musical', 367),
#  ('hilarious', 367),
#  ('enjoyed', 367),
#  ('cop', 367),
#  ('message', 366),
#  ('pay', 366),
#  ('happy', 366),
#  ('box', 365),
#  ('laughs', 365),
#  ('sadly', 363),
#  ('suspense', 363),
#  ('eye', 362),
#  ('named', 361),
#  ('similar', 361),
#  ('third', 361),
#  ('modern', 360),
#  ('failed', 359),
#  ('events', 359),
#  ('forget', 358),
#  ('question', 358),
#  ('male', 357),
#  ('finds', 357),
#  ('perfect', 356),
#  ('sister', 355),
#  ('spent', 355),
#  ('feature', 354),
#  ('result', 354),
#  ('comment', 353),
#  ('girlfriend', 353),
#  ('sexual', 352),
#  ('attempts', 351),
#  ('neither', 351),
#  ('richard', 351),
#  ('screenplay', 350),
#  ('elements', 350),
#  ('spoilers', 349),
#  ('filmmakers', 348),
#  ('showing', 348),
#  ('brain', 348),
#  ('christmas', 347),
#  ('miss', 347),
#  ('dr', 347),
#  ('cover', 345),
#  ('sequences', 344),
#  ('red', 344),
#  ('typical', 343),
#  ('excuse', 343),
#  ('crazy', 342),
#  ('ideas', 342),
#  ('baby', 342),
#  ('loved', 341),
#  ('meant', 341),
#  ('fire', 340),
#  ('worked', 340),
#  ('follow', 339),
#  ('unbelievable', 339),
#  ('theme', 337),
#  ('appear', 336),
#  ('plus', 336),
#  ('producers', 336),
#  ('twist', 336),
#  ('barely', 336),
#  ('team', 335),
#  ('directors', 335),
#  ('viewers', 333),
#  ('tom', 332),
#  ('slasher', 332),
#  ('leads', 332),
#  ('villain', 331),
#  ('working', 331),
#  ('gun', 331),
#  ('wrote', 331),
#  ('open', 330),
#  ('realize', 330),
#  ('island', 330),
#  ('strong', 330),
#  ('disappointing', 329),
#  ('positive', 329),
#  ('yeah', 329),
#  ('quickly', 329),
#  ('simple', 328),
#  ('honestly', 328),
#  ('release', 328),
#  ('weren', 328),
#  ('tells', 327),
#  ('period', 327),
#  ('kills', 327),
#  ('eventually', 327),
#  ('doctor', 327),
#  ('acted', 326),
#  ('dog', 326),
#  ('herself', 326),
#  ('nowhere', 326),
#  ('list', 326),
#  ('walk', 325),
#  ('apart', 324),
#  ('air', 324),
#  ('subject', 323),
#  ('makers', 323),
#  ('learn', 322),
#  ('fi', 322),
#  ('sci', 319),
#  ('admit', 319),
#  ('bother', 319),
#  ('disappointment', 318),
#  ('jack', 318),
#  ('note', 318),
#  ('hands', 318),
#  ('certain', 317),
#  ('value', 317),
#  ('casting', 317),
#  ('e', 317),
#  ('grade', 316),
#  ('peter', 316),
#  ('suddenly', 315),
#  ('missing', 315),
#  ('previous', 313),
#  ('break', 313),
#  ('stick', 313),
#  ('form', 313),
#  ('soundtrack', 312),
#  ('front', 311),
#  ('expecting', 311),
#  ('surprised', 311),
#  ('surprise', 310),
#  ('parents', 310),
#  ('relationship', 310),
#  ('today', 309),
#  ('shoot', 309),
#  ('painful', 308),
#  ('leaves', 308),
#  ('vampire', 308),
#  ('somewhere', 308),
#  ('ways', 308),
#  ('creepy', 308),
#  ('ended', 308),
#  ('concept', 308),
#  ('th', 307),
#  ('spend', 307),
#  ('effect', 306),
#  ('future', 306),
#  ('difficult', 306),
#  ('street', 306),
#  ('fighting', 306),
#  ('america', 305),
#  ('c', 305),
#  ('accent', 304),
#  ('truth', 302),
#  ('project', 302),
#  ('deal', 301),
#  ('joe', 301),
#  ('f', 301),
#  ('indeed', 301),
#  ('rate', 300),
#  ('biggest', 300),
#  ('paul', 299),
#  ('japanese', 299),
#  ('redeeming', 298),
#  ('college', 298),
#  ('begins', 298),
#  ('utterly', 298),
#  ('fairly', 297),
#  ('disney', 297),
#  ('york', 297),
#  ('cartoon', 296),
#  ('create', 296),
#  ('crew', 296),
#  ('revenge', 296),
#  ('outside', 295),
#  ('co', 295),
#  ('interested', 295),
#  ('computer', 295),
#  ('stage', 295),
#  ('considering', 294),
#  ('speak', 294),
#  ('among', 294),
#  ('towards', 293),
#  ('channel', 293),
#  ('sick', 293),
#  ('talented', 292),
#  ('van', 292),
#  ('hair', 292),
#  ('cause', 292),
#  ('particular', 292),
#  ('bottom', 291),
#  ('reasons', 291),
#  ('telling', 290),
#  ('cat', 290),
#  ('mediocre', 290),
#  ('store', 289),
#  ('supporting', 289),
#  ('hoping', 288),
#  ...]

# %%
pos_neg_ratios = Counter()

for term, count in list(total_count.most_common()):
    if(count > 100):
        pos_neg_ratio = positive_count[term] / (negative_count[term] + 1)
        pos_neg_ratios[term] = pos_neg_ratio

for word, ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = - np.log(1/(ratio+0.01))

# %%
pos_neg_ratios.most_common()[:30]
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.0775374439057197),
#  ('felix', 3.1527360223636558),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.8067217286092401),
#  ('victoria', 2.6810215287142909),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.5389738710582761),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.2600254785752498),
#  ('perfection', 2.1594842493533721),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.0386195471595809),
#  ('voight', 2.0301704926730531),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.9783454248084671),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
#  ('beautifully', 1.7626953362841438),
#  ('soccer', 1.7578579175523736)]

# %%
list(reversed(pos_neg_ratios.most_common()))[:30]
# Out:
# [('boll', -4.0778152602708904),
#  ('uwe', -3.9218753018711578),
#  ('seagal', -3.3202501058581921),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.7753833211707968),
#  ('incoherent', -2.7641396677532537),
#  ('unfunny', -2.5545257844967644),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('horrid', -2.3715779644809971),
#  ('pointless', -2.3451073877136341),
#  ('atrocious', -2.3187369339642556),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('drivel', -2.2476029585766928),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.1326133844207011),
#  ('wasting', -2.1178155545614512),
#  ('remotely', -2.111046881095167),
#  ('existent', -2.0024805005437076),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.9216610938019989),
#  ('sucks', -1.9166645809588516),
#  ('uninspired', -1.9131499212248517),
#  ('lame', -1.9117232884159072),
#  ('insult', -1.9085323769376259)]

# %% [markdown]
# ## Convert Text into Numbers

# %%
vocab = set(total_count.keys())
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74075

# %%
## Create empty vector
import numpy as np
layer_0 = np.zeros((1,vocab_size))
layer_0
# Out:
# array([[ 0.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
# Create word to index
word2index = {}

for i, word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'placement': 36912,
#  'taxpayers': 1,
#  'iwaya': 61533,
#  'apparel': 2,
#  'amamoto': 3,
#  'chandelier': 36376,
#  'gestured': 5,
#  'sluttishly': 6,
#  'bricks': 7,
#  'israelies': 8,
#  'mobility': 9,
#  'obers': 72416,
#  'snowman': 11,
#  'years': 12321,
#  'antidote': 12,
#  'edd': 13,
#  'mom': 14,
#  'tersteeghe': 15,
#  'dependances': 17,
#  'shrouded': 18,
#  'jasmin': 30160,
#  'unrecognizable': 65577,
#  'spongebob': 20,
#  'ballroom': 21,
#  'excelled': 22,
#  'jhene': 23,
#  'moviegoing': 24,
#  'laxitive': 34,
#  'gelding': 26,
#  'past': 27,
#  'pearl': 30,
#  'monroe': 29,
#  'hired': 49262,
#  'governess': 31,
#  'rescues': 32,
#  'danielsen': 61539,
#  'rem': 35,
#  'mendacious': 36,
#  'deem': 37,
#  'real': 38,
#  'individuated': 39,
#  'greene': 24679,
#  'suet': 42,
#  'procedurals': 4,
#  'inconsiderately': 44,
#  'filmfour': 47,
#  'patti': 46,
#  'fda': 48,
#  'scences': 51,
#  'coalwood': 24681,
#  'fiends': 4851,
#  'kneales': 53,
#  'elucubrate': 43973,
#  'unforssen': 54,
#  'shoemaker': 55,
#  'blandick': 56,
#  'hype': 58,
#  'ester': 59,
#  'deix': 61,
#  'descendants': 62,
#  'garbage': 63,
#  'piovani': 64,
#  'bears': 65,
#  'hypesters': 66,
#  'stomps': 67,
#  'contort': 68,
#  'audrina': 69,
#  'mde': 70,
#  'nvm': 71,
#  'chromosome': 12331,
#  'whether': 72,
#  'beaters': 73,
#  'comedically': 74,
#  'creation': 75,
#  'rizwan': 24685,
#  'critisism': 76,
#  'rda': 77,
#  'profoundly': 78,
#  'biarkan': 79,
#  'boiled': 80,
#  'brita': 82,
#  'income': 24688,
#  'tackily': 90,
#  'accents': 84,
#  'plagiarised': 85,
#  'fetishwear': 86,
#  'dwelt': 66269,
#  'fratlike': 12337,
#  'birdcage': 91,
#  'yelli': 92,
#  'heliports': 95,
#  'teapot': 96,
#  'subcommander': 61708,
#  'concocts': 10,
#  'turntable': 97,
#  'undifferentiated': 98,
#  'bawdy': 100,
#  'ruefully': 102,
#  'cheerfully': 36928,
#  'renuka': 103,
#  'interfered': 106,
#  'stylishness': 105,
#  'bambini': 36929,
#  'barsi': 60453,
#  'version': 107,
#  'sweats': 108,
#  'baseline': 109,
#  'mucci': 110,
#  'kartiff': 111,
#  'madnes': 61551,
#  'virgil': 112,
#  'starfleet': 114,
#  'surging': 115,
#  'harden': 116,
#  'sausages': 22780,
#  'listless': 54622,
#  'underpins': 117,
#  'blending': 24692,
#  'kintaro': 118,
#  'ki': 119,
#  'readjusts': 120,
#  'ppl': 121,
#  'objectify': 123,
#  'hunland': 126,
#  'bonjour': 125,
#  'darkies': 127,
#  'yeshua': 129,
#  'stalked': 130,
#  'pessimism': 67639,
#  'letheren': 131,
#  'eve': 132,
#  'margaux': 133,
#  'leibman': 134,
#  'cycle': 135,
#  'enthrall': 49273,
#  'hoffer': 136,
#  'guiana': 137,
#  'chiasmus': 139,
#  'flatop': 140,
#  'documental': 141,
#  'enthralling': 24700,
#  'turvy': 31270,
#  'abovementioned': 61556,
#  'directly': 143,
#  'khakee': 146,
#  'disinformation': 147,
#  'sidewinder': 148,
#  'fugly': 149,
#  'bicycle': 150,
#  'lindoi': 154,
#  'dishevelled': 155,
#  'kazaa': 44020,
#  'modot': 61561,
#  'reformed': 157,
#  'karamazov': 54713,
#  'ravera': 158,
#  'contrivance': 159,
#  'scheming': 160,
#  'threats': 161,
#  'bales': 19,
#  'swordfight': 163,
#  'slipped': 164,
#  'molina': 166,
#  'befalls': 167,
#  'elvis': 168,
#  'fatherly': 169,
#  'effortless': 170,
#  'talledega': 171,
#  'synecdoche': 172,
#  'naw': 12345,
#  'kissinger': 182,
#  'klugman': 174,
#  'liar': 180,
#  'vaults': 177,
#  'pachelbel': 178,
#  'eugene': 179,
#  'traumatized': 36937,
#  'scoobys': 181,
#  'duran': 183,
#  'taliban': 184,
#  'assassinations': 185,
#  'anachronism': 186,
#  'crewmember': 188,
#  'langdon': 190,
#  'jha': 192,
#  'corroding': 49285,
#  'rummy': 193,
#  'ratman': 195,
#  'ipolite': 197,
#  'happosai': 203,
#  'furs': 201,
#  'barters': 202,
#  'ostentation': 204,
#  'chippendale': 24713,
#  'salmonella': 206,
#  'dodds': 207,
#  'mnniskor': 208,
#  'sensation': 61568,
#  'moderns': 70454,
#  'vilifies': 209,
#  'shakesphere': 210,
#  'tome': 211,
#  'isaacs': 212,
#  'sappingly': 213,
#  'patron': 214,
#  'originators': 3486,
#  'malicious': 216,
#  'yasuzo': 217,
#  'underztand': 218,
#  'moguls': 219,
#  'bakesfield': 220,
#  'isuh': 221,
#  'trashbin': 222,
#  'almodovar': 223,
#  'tac': 28,
#  'misconceived': 227,
#  'resturant': 61575,
#  'timidly': 228,
#  'chant': 229,
#  'demonstrators': 231,
#  'blackbelts': 232,
#  'sajani': 65919,
#  'hvr': 235,
#  'blanche': 234,
#  'slew': 71639,
#  'wasp': 236,
#  'gooders': 237,
#  'bajillion': 33,
#  'epiphanies': 238,
#  'subscribing': 239,
#  'flanked': 241,
#  'forethought': 12356,
#  'kindhearted': 242,
#  'dissappointed': 243,
#  'fits': 244,
#  'cheep': 245,
#  'storywriter': 249,
#  'sacrificial': 247,
#  'overlooking': 36948,
#  'hdtv': 24719,
#  'gamekeeper': 40,
#  'meted': 250,
#  'misinterpreted': 251,
#  'elana': 252,
#  'shmatte': 61584,
#  'schmoeller': 254,
#  'morales': 255,
#  'jodorowsky': 256,
#  'kawajiri': 259,
#  'rivas': 258,
#  'incinerates': 41,
#  'riverton': 260,
#  'omnibus': 261,
#  'margot': 262,
#  'remaster': 263,
#  'toying': 11006,
#  'plead': 49299,
#  'magicfest': 264,
#  'carrington': 265,
#  'reichter': 266,
#  'nunca': 270,
#  'incarnated': 43,
#  'apalling': 269,
#  'sophomore': 271,
#  'energized': 272,
#  'bitchiness': 273,
#  'navigating': 49762,
#  'descriptor': 274,
#  'hwang': 276,
#  'comically': 277,
#  'lucking': 58460,
#  'gandolphini': 278,
#  'mankin': 279,
#  'trigger': 45,
#  'goeffrey': 281,
#  'merchant': 282,
#  'elegius': 50,
#  'wanderd': 284,
#  'brandishing': 285,
#  'hugo': 286,
#  'plodded': 287,
#  'connotation': 295,
#  'slamming': 292,
#  'crooners': 291,
#  'riffraff': 293,
#  'kno': 12372,
#  'impulses': 14882,
#  'piscipo': 302,
#  'delamere': 297,
#  'tribilistic': 301,
#  'rhetorically': 300,
#  'frontman': 72594,
#  'manouvres': 304,
#  'victis': 305,
#  'logs': 53172,
#  'amaturish': 306,
#  'spanglish': 307,
#  'mommie': 61591,
#  'tobruk': 308,
#  'demonstrably': 309,
#  'scraps': 310,
#  'redeemiing': 311,
#  'lated': 49308,
#  'faulty': 313,
#  'hussars': 315,
#  'county': 316,
#  'evicts': 317,
#  'opted': 49306,
#  'okayso': 318,
#  'coptic': 319,
#  'dreamin': 48796,
#  'abgail': 320,
#  'foresay': 24729,
#  'wopr': 321,
#  'nimri': 322,
#  'embezzling': 323,
#  'evstigneev': 324,
#  'sundayafternoon': 326,
#  'fantastically': 49311,
#  'wodehouse': 328,
#  'biblical': 329,
#  'glorfindel': 333,
#  'instant': 331,
#  'apeal': 332,
#  'gian': 334,
#  'sorry': 335,
#  'eesh': 49312,
#  'ribsi': 336,
#  'erndira': 60,
#  'damning': 60531,
#  'stockpiled': 338,
#  'blunders': 339,
#  'phallic': 49764,
#  'ritualized': 55885,
#  'ticked': 340,
#  'daddies': 62155,
#  'shay': 342,
#  'dunno': 343,
#  'manichean': 345,
#  'chooser': 346,
#  'diney': 347,
#  'skinamax': 348,
#  'assistance': 349,
#  'chanced': 350,
#  'seagall': 351,
#  'yoshiyuki': 352,
#  'hooligans': 353,
#  'penvensie': 354,
#  'inherits': 355,
#  'pea': 356,
#  'invitations': 360,
#  'vanilla': 361,
#  'cugat': 362,
#  'roves': 363,
#  'fortnight': 364,
#  'skimp': 12387,
#  'murals': 370,
#  'gibraltar': 367,
#  'aplus': 368,
#  'rereads': 372,
#  'cheesefests': 373,
#  'jog': 374,
#  'reccomend': 375,
#  'allllllll': 55750,
#  'smothers': 376,
#  'enrolled': 51931,
#  'contextual': 379,
#  'humm': 49324,
#  'rasp': 380,
#  'amours': 381,
#  'hawai': 12392,
#  'unsustainable': 382,
#  'apostle': 383,
#  'instigators': 384,
#  'buzzsaw': 385,
#  'borgesian': 386,
#  'granzow': 36963,
#  'alexanader': 387,
#  'lankford': 61602,
#  'claim': 388,
#  'injured': 389,
#  'pero': 391,
#  'masked': 36966,
#  'zeek': 392,
#  'roehler': 393,
#  'disposability': 73085,
#  'reguards': 397,
#  'sower': 36490,
#  'hanna': 36967,
#  'darnit': 53250,
#  'thoroughfare': 32732,
#  'parkinson': 398,
#  'supervise': 399,
#  'crystallized': 401,
#  'waved': 402,
#  'lenka': 403,
#  'boardwalk': 404,
#  'lyrical': 406,
#  'cathrine': 407,
#  'resold': 409,
#  'calculus': 410,
#  'iraqi': 413,
#  'scoops': 57194,
#  'basketball': 414,
#  'effect': 415,
#  'crims': 417,
#  'gibbering': 418,
#  'swede': 419,
#  'igniting': 421,
#  'mendum': 423,
#  'echos': 424,
#  'rochefort': 24747,
#  'striesand': 425,
#  'shuttles': 430,
#  'suspected': 427,
#  'worthlessness': 428,
#  'oilwell': 429,
#  'likeliness': 61606,
#  'catwomanly': 431,
#  'seldomely': 12405,
#  'reminding': 433,
#  'locoformovies': 437,
#  'chiaureli': 438,
#  'growing': 436,
#  'undertakings': 439,
#  'mendizbal': 446,
#  'height': 442,
#  'belyt': 443,
#  'proportionality': 444,
#  'sitting': 448,
#  'rave': 61609,
#  'sleeze': 449,
#  'rooten': 450,
#  'montmartre': 451,
#  'tarasco': 453,
#  'mesmerising': 454,
#  'estelle': 455,
#  'personages': 456,
#  'harvested': 457,
#  'viver': 458,
#  'penry': 44788,
#  'dialectic': 49334,
#  'gratituous': 459,
#  'consign': 467,
#  'feeder': 461,
#  'kaboud': 464,
#  'illumination': 463,
#  'su': 465,
#  'sorbo': 468,
#  'disabling': 469,
#  'sandburgs': 472,
#  'heritage': 473,
#  'meandered': 475,
#  'mohd': 476,
#  'swampy': 478,
#  'did': 479,
#  'stanislavski': 480,
#  'dundee': 482,
#  'ashcroft': 483,
#  'tyler': 484,
#  'spear': 12416,
#  'rumours': 485,
#  'fro': 58235,
#  'elites': 486,
#  'serrault': 49339,
#  'patterns': 487,
#  'clarksburg': 492,
#  'watcher': 489,
#  'grable': 491,
#  'tapdancing': 494,
#  'sichuan': 49342,
#  'hearth': 496,
#  'boating': 36983,
#  'jazzman': 497,
#  'hiltz': 63280,
#  'spoil': 52596,
#  'quarrelling': 498,
#  'cockfight': 501,
#  'gci': 500,
#  'tingles': 61617,
#  'blackton': 502,
#  'kammerud': 503,
#  'humanity': 36985,
#  'africans': 506,
#  'devon': 505,
#  'grossed': 507,
#  'markings': 508,
#  'spacial': 509,
#  'aparthied': 513,
#  'sumptuously': 514,
#  'saawariya': 515,
#  'preordained': 519,
#  'westernised': 70460,
#  'historically': 520,
#  'emasculating': 521,
#  'suposed': 524,
#  'questionnaire': 523,
#  'sonatine': 525,
#  'dimples': 526,
#  'dren': 81,
#  'tripwires': 532,
#  'bagatelle': 529,
#  'funny': 530,
#  'surfaces': 531,
#  'rawhide': 51452,
#  'backwoodsman': 24767,
#  'binysh': 12420,
#  'kafkaesque': 70315,
#  'torturro': 538,
#  'giannini': 535,
#  'polk': 536,
#  'proyas': 537,
#  'trotwood': 539,
#  'printed': 52011,
#  'formalism': 540,
#  'farmhouse': 542,
#  'weezer': 543,
#  'yoo': 544,
#  'sock': 545,
#  'playng': 36993,
#  'ranjit': 546,
#  'dreyfuss': 550,
#  'mezrich': 548,
#  'circuitry': 549,
#  'unmask': 551,
#  'goran': 552,
#  'methuselah': 71439,
#  'briley': 83,
#  'bikram': 553,
#  'sic': 554,
#  'trilling': 12422,
#  'callup': 555,
#  'timelines': 88,
#  'authorizes': 558,
#  'instants': 64551,
#  'lafayette': 559,
#  'combust': 560,
#  'befriending': 561,
#  'marble': 562,
#  'stages': 563,
#  'vanishes': 564,
#  'masonic': 565,
#  'novelists': 566,
#  'savvy': 568,
#  'fortier': 569,
#  'pote': 570,
#  'ler': 573,
#  'obsessives': 33799,
#  'overhyped': 574,
#  'compartments': 575,
#  'austrailian': 576,
#  'includesraymond': 580,
#  'decider': 578,
#  'levant': 579,
#  'levar': 581,
#  'schwarzenneger': 582,
#  'boooooooo': 583,
#  'irrelevant': 584,
#  'practiced': 69435,
#  'jelinek': 586,
#  'etiienne': 594,
#  'delle': 592,
#  'permeating': 589,
#  'november': 590,
#  'innocous': 593,
#  'caricaturing': 595,
#  'domino': 597,
#  'prayers': 599,
#  'nile': 600,
#  'cliquey': 601,
#  'peak': 602,
#  'thebom': 603,
#  'audibly': 606,
#  'morrissey': 61470,
#  'anally': 608,
#  'acquitted': 37006,
#  'hollar': 611,
#  'spin': 612,
#  'crapstory': 614,
#  'gentrified': 615,
#  'hallow': 616,
#  'miller': 617,
#  'overreacts': 619,
#  'hendler': 622,
#  'payaso': 626,
#  'limb': 623,
#  'strolled': 625,
#  'blitzkriegs': 24780,
#  'aria': 627,
#  'oligarchy': 68466,
#  'galicia': 628,
#  'papers': 70220,
#  'mewing': 629,
#  'advan': 630,
#  'perplexedly': 634,
#  'blomkamp': 635,
#  'augusta': 633,
#  'acquainted': 62190,
#  'innapropriate': 4564,
#  'draining': 637,
#  'mythic': 639,
#  'kop': 640,
#  'rodolphe': 644,
#  'barman': 642,
#  'hawkeye': 643,
#  'birthmark': 645,
#  'popular': 646,
#  'milfune': 647,
#  'monaghan': 37011,
#  'akcent': 652,
#  'taiwanese': 650,
#  'azoic': 651,
#  'scalp': 653,
#  'liken': 24785,
#  'isral': 49360,
#  'sarcastic': 654,
#  'deadly': 655,
#  'running': 656,
#  'noted': 657,
#  'primo': 24787,
#  'sensationalized': 658,
#  'grahame': 659,
#  'bersen': 99,
#  'chooses': 660,
#  'animation': 661,
#  'unenjoyable': 662,
#  'nonstraight': 63683,
#  'specie': 664,
#  'lize': 665,
#  'radha': 666,
#  'guesses': 101,
#  'mathias': 667,
#  'mumu': 668,
#  'affectations': 49364,
#  'vaugn': 670,
#  'demin': 675,
#  'manierism': 672,
#  'digress': 673,
#  'siberia': 674,
#  'juarez': 676,
#  'fishhooks': 104,
#  'stockler': 24791,
#  'especially': 68846,
#  'wigged': 65082,
#  'madding': 677,
#  'ghetto': 678,
#  'hostile': 679,
#  'burnett': 680,
#  'ritt': 681,
#  'pathologize': 62367,
#  'pascow': 682,
#  'rifle': 61655,
#  'costing': 683,
#  'asesino': 684,
#  'aikidoist': 49369,
#  'muppeteers': 37017,
#  'chittering': 685,
#  'manette': 686,
#  'uprightness': 687,
#  'tuvoc': 65773,
#  'woodland': 24796,
#  'ossuary': 688,
#  'francs': 689,
#  'oriented': 690,
#  'voogdt': 692,
#  'carolers': 694,
#  'texan': 695,
#  'griswalds': 61648,
#  'unprejudiced': 12439,
#  'tarradiddle': 700,
#  'liberated': 697,
#  'rostotsky': 698,
#  'corpsei': 699,
#  'coool': 55593,
#  'formula': 702,
#  'bannings': 68960,
#  'smirky': 703,
#  'disarmed': 35486,
#  'manicured': 704,
#  'courtin': 71342,
#  'beckert': 705,
#  'resnick': 706,
#  'kurta': 707,
#  'mensch': 708,
#  'polynesia': 712,
#  'kerr': 710,
#  'parley': 711,
#  'machinal': 713,
#  'quentin': 61649,
#  'collectibles': 716,
#  'ukranian': 24797,
#  'silage': 720,
#  'hitchcockometer': 718,
#  'signage': 721,
#  'anorectic': 722,
#  'congratulations': 723,
#  'montes': 724,
#  'bidder': 725,
#  'earthquake': 727,
#  'patrica': 728,
#  'siegel': 730,
#  'sensational': 731,
#  'thanked': 736,
#  'peculiar': 735,
#  'inhabitants': 737,
#  'calendar': 739,
#  'decibels': 740,
#  'ql': 741,
#  'starving': 49380,
#  'sose': 743,
#  'ntuba': 744,
#  'suckotrocity': 745,
#  'behavior': 113,
#  'tutelage': 746,
#  'unused': 747,
#  'edmund': 49383,
#  'schleps': 748,
#  'councellor': 749,
#  'holey': 752,
#  'gaffari': 753,
#  'elocution': 754,
#  'ingrid': 756,
#  'pleasure': 757,
#  'holmfrid': 760,
#  'genie': 761,
#  'backlash': 762,
#  'fleapit': 763,
#  'rotld': 765,
#  'associating': 772,
#  'gabble': 767,
#  'ril': 61662,
#  'elefant': 51858,
#  'chulawasse': 770,
#  'burlesqued': 61664,
#  'drovers': 773,
#  'farlan': 774,
#  'houck': 24804,
#  'debussy': 775,
#  'toothpaste': 777,
#  'unredemable': 778,
#  'heartwrenching': 24810,
#  'punters': 780,
#  'weird': 782,
#  'jalouse': 783,
#  'shiftless': 784,
#  'screenin': 62514,
#  'cremated': 26237,
#  'bando': 58250,
#  'painkiller': 786,
#  'deverell': 787,
#  'panky': 788,
#  'resigning': 791,
#  'drone': 790,
#  'ebsen': 61668,
#  'gaffe': 792,
#  'abo': 61669,
#  'curiousity': 795,
#  'dumas': 797,
#  'estimate': 798,
#  'guervara': 49391,
#  'fertility': 800,
#  'chives': 801,
#  'argues': 802,
#  'unoriginals': 803,
#  'scree': 804,
#  'horribly': 122,
#  'amazes': 805,
#  'unwavering': 806,
#  'slurping': 49394,
#  'casserole': 807,
#  'rf': 38979,
#  'brief': 808,
#  'sickroom': 809,
#  'grunwald': 810,
#  'fullest': 811,
#  'marcellous': 4490,
#  'farly': 813,
#  'seaside': 814,
#  'defecation': 818,
#  'hssh': 816,
#  'frothy': 12453,
#  'cinemax': 72112,
#  'vie': 38670,
#  'instincts': 819,
#  'grifting': 821,
#  'mattia': 33472,
#  'olympia': 822,
#  'conon': 823,
#  'jost': 824,
#  'ramgarh': 825,
#  'hairball': 128,
#  'pederast': 827,
#  'matic': 828,
#  'pulse': 829,
#  'dappled': 830,
#  'unchained': 833,
#  'shecky': 834,
#  'trasvestisment': 70935,
#  'aiming': 61674,
#  'dodeskaden': 836,
#  'marafon': 841,
#  'natives': 838,
#  'miscastings': 840,
#  'comparative': 842,
#  'reconstructed': 845,
#  'ferret': 846,
#  'alana': 847,
#  'bhang': 848,
#  'mbongeni': 40508,
#  'applauses': 849,
#  'tropics': 850,
#  'jeongg': 851,
#  'delicate': 852,
#  'tuna': 853,
#  'intergalactic': 49400,
#  'yoshi': 854,
#  'lowest': 855,
#  'repubhlic': 856,
#  'carrier': 857,
#  'levitating': 858,
#  'stealin': 860,
#  'nil': 861,
#  'marooned': 862,
#  'dummee': 863,
#  'marlyn': 864,
#  'glitzed': 865,
#  'cartoon': 61677,
#  'densest': 63688,
#  'magilla': 868,
#  'tgwwt': 869,
#  'sewn': 871,
#  'cucacha': 872,
#  'bleibtreu': 874,
#  'materialization': 9118,
#  'confederates': 876,
#  'montrealers': 877,
#  'gum': 878,
#  'consultant': 879,
#  'roughest': 882,
#  'couleur': 881,
#  'disobeying': 883,
#  'gravelings': 49406,
#  'kingdom': 884,
#  'anxiously': 885,
#  'cya': 886,
#  'reconciles': 887,
#  'reactivation': 24827,
#  'pinoy': 888,
#  'rummenigge': 24366,
#  'nikolaj': 889,
#  'proog': 24828,
#  'hatching': 890,
#  'affairs': 49408,
#  'bope': 891,
#  'broadway': 68400,
#  'novello': 892,
#  'unpleasantries': 53346,
#  'candor': 894,
#  'husks': 895,
#  'ministrations': 53190,
#  'executed': 896,
#  'labeling': 897,
#  'threlkis': 899,
#  'fists': 900,
#  'literal': 901,
#  'blystone': 902,
#  'positive': 37062,
#  'leopards': 903,
#  'demerit': 906,
#  'horsemanship': 907,
#  'chez': 3365,
#  'noirometer': 61685,
#  'flyes': 908,
#  'alissia': 37065,
#  'branaughs': 909,
#  'foreign': 910,
#  'obituary': 911,
#  'flavoring': 73848,
#  'jusenkkyo': 913,
#  'mest': 914,
#  'spree': 61686,
#  'pictograms': 915,
#  'musical': 916,
#  'sheev': 917,
#  'lightpost': 35851,
#  'grumpier': 918,
#  'pokeball': 919,
#  'buttgereit': 38189,
#  'mulder': 920,
#  'sours': 61687,
#  'faired': 922,
#  'nears': 69753,
#  'amateurishly': 923,
#  'guidos': 24838,
#  'crystal': 924,
#  'scen': 925,
#  'vapid': 12475,
#  'dharam': 926,
#  'swoony': 142,
#  'supply': 927,
#  'anticlimax': 928,
#  'owns': 929,
#  'be': 37075,
#  'flaky': 930,
#  'cocktail': 932,
#  'lethally': 936,
#  'cormon': 934,
#  'kamalini': 49415,
#  'nyu': 145,
#  'add': 937,
#  'austreim': 940,
#  'actings': 72962,
#  'balances': 941,
#  'lafontaine': 944,
#  'emsworth': 943,
#  'lieu': 945,
#  'carreyism': 946,
#  'cokehead': 947,
#  'commandant': 949,
#  'enix': 952,
#  'delusions': 950,
#  'etherything': 951,
#  'idjits': 954,
#  'allows': 24843,
#  'especically': 955,
#  'geometry': 957,
#  'barbados': 958,
#  'fiascos': 960,
#  'unblinking': 961,
#  'pretensions': 962,
#  'marseilles': 963,
#  'neuromuscular': 964,
#  'penetration': 965,
#  'goodings': 966,
#  'rassendyll': 61696,
#  'arnolds': 967,
#  'animaniacs': 968,
#  'hutt': 970,
#  'windowless': 61698,
#  'ciccolina': 975,
#  'dieing': 972,
#  'quanxiu': 973,
#  'unrefined': 974,
#  'airphone': 24846,
#  'offender': 979,
#  'haas': 977,
#  'yodeller': 978,
#  'liszt': 980,
#  'peeew': 57024,
#  'gutman': 981,
#  'glint': 982,
#  'costly': 153,
#  'gracefully': 12480,
#  'lawton': 64576,
#  'blindfold': 152,
#  'lieving': 985,
#  'bleary': 61700,
#  'racketeer': 986,
#  'wincing': 990,
#  'successions': 988,
#  'suppression': 989,
#  'playrights': 49422,
#  'appr': 992,
#  'remarks': 993,
#  'diners': 994,
#  'substantial': 995,
#  'shambles': 997,
#  'craftwork': 998,
#  'beautifulest': 999,
#  'vibrator': 1000,
#  'sistas': 1001,
#  'oeuvres': 1002,
#  'reciprocating': 1003,
#  'chaparones': 51163,
#  'hz': 73738,
#  'bushman': 1004,
#  'won': 1005,
#  'enabled': 1006,
#  'soundeffects': 68735,
#  'outset': 1007,
#  'prodigious': 1008,
#  'mademouiselle': 49424,
#  'waaaaay': 1009,
#  'domini': 24852,
#  'el': 1010,
#  'trailing': 1011,
#  'betta': 1012,
#  'analogous': 1013,
#  'scrapping': 1014,
#  'aborigone': 1015,
#  'ricochet': 28219,
#  'stupidness': 1017,
#  'dandys': 1020,
#  'conducive': 1019,
#  'erector': 1021,
#  'threefold': 1022,
#  'catherines': 1025,
#  'gabe': 1024,
#  'tip': 1026,
#  ...}

# %%
def update_input_layer(review):
    global layer_0
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews_clean[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
def get_target_for_label(label):
    if(label == "positive"):
        return 1
    else:
        return 0
get_target_for_label(labels_clean[0])
# Out:
# 1

# %% [markdown]
# ## Build Neural Network

# %%
import time
import sys
import numpy as np

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'positive'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] > 0.5):
            return "positive"
        else:
            return "negative"

# %%
mlp = SentimentNetwork(reviews_clean[:-1000], labels_clean[:-1000], learning_rate=0.1)

# %%
# evaluate our model before training (just to show how horrible it is)
mlp.test(reviews_clean[-1000:],labels_clean[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):509.6% #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %%
mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:3.58% Speed(reviews/sec):110.7 #Correct:430 #Trained:861 Training Accuracy:49.9%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-22fad3e31860> in <module>()
# ----> 1 mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
#
# <ipython-input-24-791649e0dc3b> in train(self, training_reviews, training_labels)
#     124             reviews_per_second = i / float(time.time() - start)
#     125
# --> 126             sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
#     127             if(i % 2500 == 0):
#     128                 print("")
#
# /home/isaac/anaconda3/lib/python3.5/site-packages/ipykernel/iostream.py in write(self, string)
#     369             is_child = (not self._is_master_process())
#     370             # only touch the buffer in the IO thread to avoid races
# --> 371             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     372             if is_child:
#     373                 # newlines imply flush in subprocesses
#
# /home/isaac/anaconda3/lib/python3.5/site-packages/ipykernel/iostream.py in schedule(self, f)
#     188                 event_id = os.urandom(16)
#     189             self._events[event_id] = f
# --> 190             self._event_pipe.send(event_id)
#     191         else:
#     192             f()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq/backend/cython/socket.c:7305)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq/backend/cython/socket.c:7048)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy (zmq/backend/cython/socket.c:2920)()
#
# /home/isaac/anaconda3/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9621)()
#
# KeyboardInterrupt:

# %%
mlp = SentimentNetwork(reviews_clean[:-1000],labels_clean[:-1000], learning_rate=0.01)

# %%
# train the network
mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:2.70% Speed(reviews/sec):119.5 #Correct:322 #Trained:650 Training Accuracy:49.5%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-dccd702b61f7> in <module>()
#       1 # train the network
# ----> 2 mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
#
# <ipython-input-24-791649e0dc3b> in train(self, training_reviews, training_labels)
#     117             # TODO: Update the weights
#     118             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 119             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     120
#     121             if(np.abs(layer_2_error) < 0.5):
#
# KeyboardInterrupt:

# %%
mlp = SentimentNetwork(reviews_clean[:-1000],labels_clean[:-1000], learning_rate=0.001)

# %%
# train the network
mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:4.90% Speed(reviews/sec):111.7 #Correct:581 #Trained:1178 Training Accuracy:49.3%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-dccd702b61f7> in <module>()
#       1 # train the network
# ----> 2 mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
#
# <ipython-input-24-791649e0dc3b> in train(self, training_reviews, training_labels)
#     117             # TODO: Update the weights
#     118             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 119             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     120
#     121             if(np.abs(layer_2_error) < 0.5):
#
# KeyboardInterrupt:

# %% [markdown]
# ## By reducing the learning rate, the neural network is not improving the accuracy fast enough, so we need to change the structure to improve the model
#
# ### Analyze the signal vs. noise
#
# ## Understand Neural Noise

# %%
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
list(vocab)[0]
# A noise here
# Out:
# ''

# %%
reviews_clean[0].split(" ")
# A lot of empty, period
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  '.',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  '',
#  'such',
#  'as',
#  '',
#  'teachers',
#  '',
#  '.',
#  'my',
#  '',
#  '',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  '',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  '',
#  'teachers',
#  '',
#  '.',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  '',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  '',
#  'pomp',
#  '',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  '',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  '.',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  '',
#  'i',
#  'immediately',
#  'recalled',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'at',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'high',
#  '.',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  '',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  '.',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  '.',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  '.',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  '',
#  't',
#  '',
#  '',
#  '']

# %%
# Check how many period is in the review
review_counter = Counter()
for word in reviews_clean[0].split(" "):
    review_counter[word] += 1
review_counter.most_common()
# The result below shows the dominant word has nothing to do
# with the sentiment, the weighting has a dominant effect on the hidden layer
# the count weighs heavily on the noise
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('high', 5),
#  ('i', 5),
#  ('a', 4),
#  ('bromwell', 4),
#  ('is', 4),
#  ('that', 4),
#  ('teachers', 4),
#  ('of', 4),
#  ('at', 2),
#  ('school', 2),
#  ('in', 2),
#  ('student', 2),
#  ('students', 2),
#  ('their', 2),
#  ('me', 2),
#  ('my', 2),
#  ('as', 2),
#  ('it', 2),
#  ('scramble', 1),
#  ('right', 1),
#  ('situation', 1),
#  ('believe', 1),
#  ('such', 1),
#  ('reality', 1),
#  ('about', 1),
#  ('other', 1),
#  ('your', 1),
#  ('life', 1),
#  ('comedy', 1),
#  ('same', 1),
#  ('years', 1),
#  ('sack', 1),
#  ('pomp', 1),
#  ('pettiness', 1),
#  ('pathetic', 1),
#  ('satire', 1),
#  ('tried', 1),
#  ('which', 1),
#  ('than', 1),
#  ('survive', 1),
#  ('down', 1),
#  ('far', 1),
#  ('can', 1),
#  ('what', 1),
#  ('recalled', 1),
#  ('t', 1),
#  ('financially', 1),
#  ('whole', 1),
#  ('line', 1),
#  ('classic', 1),
#  ('one', 1),
#  ('much', 1),
#  ('think', 1),
#  ('welcome', 1),
#  ('episode', 1),
#  ('ran', 1),
#  ('age', 1),
#  ('immediately', 1),
#  ('saw', 1),
#  ('m', 1),
#  ('closer', 1),
#  ('repeatedly', 1),
#  ('profession', 1),
#  ('knew', 1),
#  ('programs', 1),
#  ('expect', 1),
#  ('many', 1),
#  ('remind', 1),
#  ('cartoon', 1),
#  ('adults', 1),
#  ('isn', 1),
#  ('time', 1),
#  ('see', 1),
#  ('lead', 1),
#  ('through', 1),
#  ('teaching', 1),
#  ('who', 1),
#  ('pity', 1),
#  ('when', 1),
#  ('insightful', 1),
#  ('schools', 1),
#  ('fetched', 1),
#  ('all', 1),
#  ('some', 1),
#  ('here', 1),
#  ('s', 1),
#  ('inspector', 1),
#  ('burn', 1),
#  ('and', 1)]

# %% [markdown]
# ## Reducing Noise in the Network

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork_2:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] = 1
        # While update layers, do not increment, change the counts to binary
        # eliminate neural noises
        
    def get_target_for_label(self,label):
        if(label == 'positive'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] > 0.5):
            return "positive"
        else:
            return "negative"

# %%
mlp_2 = SentimentNetwork_2(reviews_clean[:-1000], labels_clean[:-1000], learning_rate = 0.1)

# %%
mlp_2.train(reviews_clean[:-1000], labels_clean[:-1000])
#Significant improvement after removing noise
#But the training speed seems really slow a.k.a inefficient
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:10.4% Speed(reviews/sec):90.52 #Correct:1814 #Trained:2501 Training Accuracy:72.5%
# Progress:20.8% Speed(reviews/sec):84.59 #Correct:3791 #Trained:5001 Training Accuracy:75.8%
# Progress:31.2% Speed(reviews/sec):82.19 #Correct:5870 #Trained:7501 Training Accuracy:78.2%
# Progress:41.6% Speed(reviews/sec):79.24 #Correct:8018 #Trained:10001 Training Accuracy:80.1%
# Progress:52.0% Speed(reviews/sec):78.76 #Correct:10145 #Trained:12501 Training Accuracy:81.1%
# Progress:52.4% Speed(reviews/sec):78.75 #Correct:10215 #Trained:12581 Training Accuracy:81.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-9f357b6ebc51> in <module>()
# ----> 1 mlp_2.train(reviews_clean[:-1000], labels_clean[:-1000])
#       2 #Significant improvement after removing noise
#       3 #But the training speed seems really slow a.k.a inefficient
#
# <ipython-input-36-87e087a17398> in train(self, training_reviews, training_labels)
#     119             # TODO: Update the weights
#     120             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 121             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     122
#     123             if(np.abs(layer_2_error) < 0.5):
#
# KeyboardInterrupt:

# %%
mlp_2.test(reviews_clean[-1000:], labels_clean[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):462.8% #Correct:814 #Tested:1000 Testing Accuracy:81.4%

# %% [markdown]
# ## Inefficiency is caused by the large zeros input
# 1. Only care about the non-zero input calculation in the neural network
# 2. 1 multiplication is also wasting time
#
# ## Increase code efficiency

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork_3:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
        self.layer_1 = np.zeros((1,hidden_nodes))
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] = 1
        # While update layers, do not increment, change the counts to binary
        # eliminate neural noises
        
    def get_target_for_label(self,label):
        if(label == 'positive'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            # Can completely skip generating input layer
            # self.update_input_layer(review)

            # Hidden layer
            # layer_1 = self.layer_0.dot(self.weights_0_1)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]
            
            # Output layer
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            #self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
            
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate
            
            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        start = time.time()
        correct = 0
        
        
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start + 0.000001)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer
        

        # Hidden layer
        self.layer_1 *= 0
        unique_indices = set()
        
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
            
        # Output layer
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] > 0.5):
            return "positive"
        else:
            return "negative"

# %%
mlp_3 = SentimentNetwork_3(reviews_clean[:-1000], labels_clean[:-1000], learning_rate=0.1)

# %%
mlp_3.train(reviews_clean[:-1000], labels_clean[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:10.4% Speed(reviews/sec):621.9 #Correct:1808 #Trained:2501 Training Accuracy:72.2%
# Progress:20.8% Speed(reviews/sec):580.0 #Correct:3807 #Trained:5001 Training Accuracy:76.1%
# Progress:31.2% Speed(reviews/sec):553.1 #Correct:5903 #Trained:7501 Training Accuracy:78.6%
# Progress:41.6% Speed(reviews/sec):548.3 #Correct:8027 #Trained:10001 Training Accuracy:80.2%
# Progress:52.0% Speed(reviews/sec):543.4 #Correct:10161 #Trained:12501 Training Accuracy:81.2%
# Progress:62.5% Speed(reviews/sec):525.1 #Correct:12294 #Trained:15001 Training Accuracy:81.9%
# Progress:72.9% Speed(reviews/sec):500.4 #Correct:14395 #Trained:17501 Training Accuracy:82.2%
# Progress:83.3% Speed(reviews/sec):503.9 #Correct:16570 #Trained:20001 Training Accuracy:82.8%
# Progress:93.7% Speed(reviews/sec):501.3 #Correct:18750 #Trained:22501 Training Accuracy:83.3%
# Progress:99.9% Speed(reviews/sec):495.6 #Correct:20077 #Trained:24000 Training Accuracy:83.6%

# %%
mlp_3.test(reviews_clean[-1000:], labels_clean[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):835.6% #Correct:848 #Tested:1000 Testing Accuracy:84.8%

# %%
import time
import sys

# Let's tweak our network from before to model these phenomena
class SentimentNetwork_3T:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        np.random.seed(1)
    
        self.pre_process_data(reviews)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self,reviews):
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
        self.layer_1 = np.zeros((1,hidden_nodes))
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            self.layer_0[0][self.word2index[word]] = 1

    def get_target_for_label(self,label):
        if(label == 'positive'):
            return 1
        else:
            return 0
        
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer

            # Hidden layer
#             layer_1 = self.layer_0.dot(self.weights_0_1)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]
            
            # Output layer
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
        
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start + 0.0000001)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer


        # Hidden layer
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] > 0.5):
            return "positive"
        else:
            return "negative"

# %%
mlp_3_T = SentimentNetwork_3T(reviews_clean[:-1000], labels_clean[:-1000], learning_rate=0.1)

# %%
mlp_3_T.train(reviews_clean[:-1000], labels_clean[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):578.7 #Correct:20077 #Trained:24000 Training Accuracy:83.6%

# %%
mlp_3_T.train(reviews_clean[:-1000] * 2, labels_clean[:-1000] * 2)
# Out:
# Progress:99.9% Speed(reviews/sec):912.1 #Correct:43864 #Trained:48000 Training Accuracy:91.3%

# %%
mlp_3_T.test(reviews_clean[-1000:]*2, labels_clean[-1000:]*2)
# Out:
# Progress:99.9% Speed(reviews/sec):951.6% #Correct:1696 #Tested:2000 Testing Accuracy:84.8%

# %% [markdown]
# ## Further Noise Reduction

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.0775374439057197),
#  ('felix', 3.1527360223636558),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.8067217286092401),
#  ('victoria', 2.6810215287142909),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.5389738710582761),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.2600254785752498),
#  ('perfection', 2.1594842493533721),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.0386195471595809),
#  ('voight', 2.0301704926730531),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.9783454248084671),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
#  ('beautifully', 1.7626953362841438),
#  ('soccer', 1.7578579175523736),
#  ('elvira', 1.7397031072720019),
#  ('underrated', 1.7197859696029656),
#  ('gripping', 1.7165360479904674),
#  ('superb', 1.7091514458966952),
#  ('delight', 1.6714733033535532),
#  ('welles', 1.6677068205580761),
#  ('sadness', 1.663505133704376),
#  ('sinatra', 1.6389967146756448),
#  ('touching', 1.637217476541176),
#  ('timeless', 1.62924053973028),
#  ('macy', 1.6211339521972916),
#  ('unforgettable', 1.6177367152487956),
#  ('favorites', 1.6158688027643908),
#  ('stewart', 1.6119987332957739),
#  ('sullivan', 1.6094379124341003),
#  ('extraordinary', 1.6094379124341003),
#  ('hartley', 1.6094379124341003),
#  ('brilliantly', 1.5950491749820008),
#  ('friendship', 1.5677652160335325),
#  ('wonderful', 1.5645425925262093),
#  ('palma', 1.5553706911638245),
#  ('magnificent', 1.54663701119507),
#  ('finest', 1.5462590108125689),
#  ('jackie', 1.5439233053234738),
#  ('ritter', 1.5404450409471491),
#  ('tremendous', 1.5184661342283736),
#  ('freedom', 1.5091151908062312),
#  ('fantastic', 1.5048433868558566),
#  ('terrific', 1.5026699370083942),
#  ('sidney', 1.493925025312256),
#  ('noir', 1.493925025312256),
#  ('outstanding', 1.4910053152089213),
#  ('pleasantly', 1.4894785973551214),
#  ('mann', 1.4894785973551214),
#  ('nancy', 1.488077055429833),
#  ('marie', 1.4825711915553104),
#  ('marvelous', 1.4739999415389962),
#  ('excellent', 1.4647538505723599),
#  ('ruth', 1.4596256342054401),
#  ('stanwyck', 1.4412101187160054),
#  ('widmark', 1.4350845252893227),
#  ('splendid', 1.4271163556401458),
#  ('chan', 1.423108334242607),
#  ('exceptional', 1.4201959127955721),
#  ('tender', 1.410986973710262),
#  ('gentle', 1.4078005663408544),
#  ('poignant', 1.4022947024663317),
#  ('gem', 1.3932148039644643),
#  ('amazing', 1.3919815802404802),
#  ('chilling', 1.3862943611198906),
#  ('davies', 1.3862943611198906),
#  ('fisher', 1.3862943611198906),
#  ('captivating', 1.3862943611198906),
#  ('darker', 1.3652409519220583),
#  ('april', 1.3499267169490159),
#  ('kelly', 1.3461743673304654),
#  ('blake', 1.3418425985490567),
#  ('overlooked', 1.329135947279942),
#  ('ralph', 1.32818673031261),
#  ('bette', 1.3156767939059373),
#  ('hoffman', 1.3150668518315229),
#  ('cole', 1.3121863889661687),
#  ('shines', 1.3049487216659381),
#  ('powerful', 1.2999662776313934),
#  ('notch', 1.2950456896547455),
#  ('remarkable', 1.2883688239495823),
#  ('pitt', 1.286210902562908),
#  ('winters', 1.2833463918674481),
#  ('vivid', 1.2762934659055623),
#  ('gritty', 1.2757524867200667),
#  ('giallo', 1.2745029551317739),
#  ('portrait', 1.2704625455947689),
#  ('innocence', 1.2694300209805796),
#  ('psychiatrist', 1.2685113254635072),
#  ('favorite', 1.2668956297860055),
#  ('ensemble', 1.2656663733312759),
#  ('stunning', 1.2622417124499117),
#  ('burns', 1.259880436264232),
#  ('garbo', 1.258954938743289),
#  ('barbara', 1.2580400255962119),
#  ('philip', 1.2527629684953681),
#  ('panic', 1.2527629684953681),
#  ('holly', 1.2527629684953681),
#  ('carol', 1.2481440226390734),
#  ('perfect', 1.246742480713785),
#  ('appreciated', 1.2462482874741743),
#  ('favourite', 1.2411123512753928),
#  ('journey', 1.2367626271489269),
#  ('rural', 1.235471471385307),
#  ('bond', 1.2321436812926323),
#  ('builds', 1.2305398317106577),
#  ('brilliant', 1.2287554137664785),
#  ('brooklyn', 1.2286654169163074),
#  ('von', 1.225175011976539),
#  ('unfolds', 1.2163953243244932),
#  ('recommended', 1.2163953243244932),
#  ('daniel', 1.20215296760895),
#  ('perfectly', 1.1971931173405572),
#  ('crafted', 1.1962507582320256),
#  ('prince', 1.1939224684724346),
#  ('troubled', 1.192138346678933),
#  ('consequences', 1.1865810616140668),
#  ('haunting', 1.1814999484738773),
#  ('cinderella', 1.180052620608284),
#  ('alexander', 1.1759989522835299),
#  ('emotions', 1.1753049094563641),
#  ('boxing', 1.1735135968412274),
#  ('subtle', 1.1734135017508081),
#  ('curtis', 1.1649873576129823),
#  ('rare', 1.1566438362402944),
#  ('loved', 1.1563661500586044),
#  ('daughters', 1.1526795099383853),
#  ('courage', 1.1438688802562305),
#  ('dentist', 1.1426722784621401),
#  ('highly', 1.1420208631618658),
#  ('nominated', 1.1409146683587992),
#  ('tony', 1.1397491942285991),
#  ('draws', 1.1325138403437911),
#  ('everyday', 1.1306150197542835),
#  ('contrast', 1.1284652518177909),
#  ('cried', 1.1213405397456659),
#  ('fabulous', 1.1210851445201684),
#  ('ned', 1.120591195386885),
#  ('fay', 1.120591195386885),
#  ('emma', 1.1184149159642893),
#  ('sensitive', 1.113318436057805),
#  ('smooth', 1.1089750757036563),
#  ('dramas', 1.1080910326226534),
#  ('today', 1.1050431789984001),
#  ('helps', 1.1023091505494358),
#  ('inspiring', 1.0986122886681098),
#  ('jimmy', 1.0937696641923216),
#  ('awesome', 1.0931328229034842),
#  ('unique', 1.0881409888008142),
#  ('tragic', 1.0871835928444868),
#  ('intense', 1.0870514662670339),
#  ('stellar', 1.0857088838322018),
#  ('rival', 1.0822184788924332),
#  ('provides', 1.0797081340289569),
#  ('depression', 1.0782034170369026),
#  ('shy', 1.0775588794702773),
#  ('carrie', 1.076139432816051),
#  ('blend', 1.0753554265038423),
#  ('hank', 1.0736109864626924),
#  ('adorable', 1.0726368022648489),
#  ('diana', 1.0726368022648489),
#  ('unexpected', 1.0722255334949147),
#  ('achievement', 1.0668635903535293),
#  ('bettie', 1.0663514264498881),
#  ('happiness', 1.0632729222228008),
#  ('glorious', 1.0608719606852626),
#  ('davis', 1.0541605260972757),
#  ('terrifying', 1.0525211814678428),
#  ('beauty', 1.050410186850232),
#  ('ideal', 1.0479685558493548),
#  ('fears', 1.0467872208035236),
#  ('hong', 1.0438040521731147),
#  ('seasons', 1.0433496099930604),
#  ('fascinating', 1.0414538748281612),
#  ('carries', 1.0345904299031787),
#  ('satisfying', 1.0321225473992768),
#  ('definite', 1.0319209141694374),
#  ('touched', 1.0296194171811581),
#  ('greatest', 1.0248947127715422),
#  ('creates', 1.0241097613701886),
#  ('aunt', 1.023388867430522),
#  ('walter', 1.022328983918479),
#  ('spectacular', 1.0198314108149955),
#  ('portrayal', 1.0189810189761024),
#  ('ann', 1.0127808528183286),
#  ('enterprise', 1.0116009116784799),
#  ('musicals', 1.0096648026516135),
#  ('deeply', 1.0094845087721023),
#  ('incredible', 1.0061677561461084),
#  ('mature', 1.0060195018402847),
#  ('margaret', 0.99682959435816731),
#  ('triumph', 0.99682959435816731),
#  ('navy', 0.99493385919326827),
#  ('harry', 0.99176919305006062),
#  ('lucas', 0.990398704027877),
#  ('sweet', 0.98966110487955483),
#  ('joey', 0.98794672078059009),
#  ('oscar', 0.98721905111049713),
#  ('balance', 0.98649499054740353),
#  ('warm', 0.98485340331145166),
#  ('ages', 0.98449898190068863),
#  ('guilt', 0.98082925301172619),
#  ('glover', 0.98082925301172619),
#  ('carrey', 0.98082925301172619),
#  ('learns', 0.97881108885548895),
#  ('unusual', 0.97788374278196932),
#  ('sons', 0.97777581552483595),
#  ('complex', 0.97761897738147796),
#  ('essence', 0.97753435711487369),
#  ('brazil', 0.9769153536905899),
#  ('widow', 0.97650959186720987),
#  ('solid', 0.97537964824416146),
#  ('beautiful', 0.97326301262841053),
#  ('holmes', 0.97246100334120955),
#  ('awe', 0.97186058302896583),
#  ('vhs', 0.97116734209998934),
#  ('eerie', 0.97116734209998934),
#  ('lonely', 0.96873720724669754),
#  ('grim', 0.96873720724669754),
#  ('sport', 0.96825047080486615),
#  ('debut', 0.96508089604358704),
#  ('destiny', 0.96343751029985703),
#  ('thrillers', 0.96281074750904794),
#  ('tears', 0.95977584381389391),
#  ('rose', 0.95664202739772253),
#  ('ginger', 0.95551144502743635),
#  ('feelings', 0.95551144502743635),
#  ('winning', 0.95471810900804055),
#  ('stanley', 0.95387344302319799),
#  ('cox', 0.95343027882361187),
#  ('paris', 0.95278479030472663),
#  ('heart', 0.95238806924516806),
#  ('hooked', 0.95155887071161305),
#  ('comfortable', 0.94803943018873538),
#  ('mgm', 0.94446160884085151),
#  ('masterpiece', 0.94155039863339296),
#  ('themes', 0.94118828349588235),
#  ('danny', 0.93967118051821874),
#  ('anime', 0.93378388932167222),
#  ('perry', 0.93328830824272613),
#  ('joy', 0.93301752567946861),
#  ('lovable', 0.93081883243706487),
#  ('mysteries', 0.92953595862417571),
#  ('hal', 0.92953595862417571),
#  ('louis', 0.92871325187271225),
#  ('charming', 0.92520609553210742),
#  ('urban', 0.92367083917177761),
#  ('allows', 0.92183091224977043),
#  ('impact', 0.91815814604895041),
#  ('italy', 0.91629073187415511),
#  ('gradually', 0.91629073187415511),
#  ('lifestyle', 0.91629073187415511),
#  ('spy', 0.91289514287301687),
#  ('treat', 0.91193342650519937),
#  ('subsequent', 0.91056005716517008),
#  ('kennedy', 0.90981821736853763),
#  ('loving', 0.90967549275543591),
#  ('surprising', 0.90937028902958128),
#  ('quiet', 0.90648673177753425),
#  ('winter', 0.90624039602065365),
#  ('reveals', 0.90490540964902977),
#  ('raw', 0.90445627422715225),
#  ('funniest', 0.90078654533818991),
#  ('pleased', 0.89994159387262562),
#  ('norman', 0.89994159387262562),
#  ('thief', 0.89874642222324552),
#  ('season', 0.89827222637147675),
#  ('secrets', 0.89794159320595857),
#  ('colorful', 0.89705936994626756),
#  ('highest', 0.8967461358011849),
#  ('compelling', 0.89462923509297576),
#  ('danes', 0.89248008318043659),
#  ('castle', 0.88967708335606499),
#  ('kudos', 0.88889175768604067),
#  ('great', 0.88810470901464589),
#  ('subtitles', 0.88730319500090271),
#  ('baseball', 0.88730319500090271),
#  ('bleak', 0.88730319500090271),
#  ('winner', 0.88643776872447388),
#  ('tragedy', 0.88563699078315261),
#  ('todd', 0.88551907320740142),
#  ('nicely', 0.87924946019380601),
#  ('arthur', 0.87546873735389985),
#  ('essential', 0.87373111745535925),
#  ('gorgeous', 0.8731725250935497),
#  ('fonda', 0.87294029100054127),
#  ('eastwood', 0.87139541196626402),
#  ('focuses', 0.87082835779739776),
#  ('enjoyed', 0.87070195951624607),
#  ('natural', 0.86997924506912838),
#  ('intensity', 0.86835126958503595),
#  ('witty', 0.86824103423244681),
#  ('rob', 0.8642954367557748),
#  ('worlds', 0.86377269759070874),
#  ('health', 0.86113891179907498),
#  ('magical', 0.85953791528170564),
#  ('deeper', 0.85802182375017932),
#  ('lucy', 0.85618680780444956),
#  ('moving', 0.85566611005772031),
#  ('lovely', 0.85290640004681306),
#  ('purple', 0.8513711857748395),
#  ('memorable', 0.84801189112086062),
#  ('sings', 0.84729786038720367),
#  ('modesty', 0.84342938360928321),
#  ('craig', 0.84342938360928321),
#  ('relate', 0.84326559685926517),
#  ('episodes', 0.84223712084137292),
#  ('strong', 0.84167135777060931),
#  ('smith', 0.83959811108590054),
#  ('tear', 0.83704136022001441),
#  ('apartment', 0.83333115290549531),
#  ('disagree', 0.83290912293510388),
#  ('princess', 0.83290912293510388),
#  ('kung', 0.83173334384609199),
#  ('adventure', 0.83150561393278388),
#  ('columbo', 0.82667857318446791),
#  ('jake', 0.82667857318446791),
#  ('adds', 0.82485652591452319),
#  ('hart', 0.82472353834866463),
#  ('strength', 0.82417544296634937),
#  ('realizes', 0.82360006895738058),
#  ('dave', 0.8232003088081431),
#  ('childhood', 0.82208086393583857),
#  ('forbidden', 0.81989888619908913),
#  ('tight', 0.81883539572344199),
#  ('surreal', 0.8178506590609026),
#  ('manager', 0.81770990320170756),
#  ('dancer', 0.81574950265227764),
#  ('con', 0.81093021621632877),
#  ('studios', 0.81093021621632877),
#  ('miike', 0.80821651034473263),
#  ('realistic', 0.80807714723392232),
#  ('explicit', 0.80792269515237358),
#  ('kurt', 0.8060875917405409),
#  ('deals', 0.80535917116687328),
#  ('traditional', 0.80535917116687328),
#  ('holds', 0.80493858654806194),
#  ('carl', 0.80437281567016972),
#  ('touches', 0.80396154690023547),
#  ('gene', 0.80314807577427383),
#  ('albert', 0.8027669055771679),
#  ('abc', 0.80234647252493729),
#  ('cry', 0.80011930011211307),
#  ('sides', 0.7995275841185171),
#  ('eyre', 0.79850769621777162),
#  ('develops', 0.79850769621777162),
#  ('dances', 0.79694397424158891),
#  ('oscars', 0.79633141679517616),
#  ('legendary', 0.79600456599965308),
#  ('hearted', 0.79492987486988764),
#  ('importance', 0.79492987486988764),
#  ('portraying', 0.79356592830699269),
#  ('impressed', 0.79258107754813223),
#  ('waters', 0.79112758892014912),
#  ('empire', 0.79078565012386137),
#  ('edge', 0.789774016249017),
#  ('jean', 0.78845736036427028),
#  ('environment', 0.78845736036427028),
#  ('sentimental', 0.7864791203521645),
#  ('captured', 0.78623760362595729),
#  ('daring', 0.78592891401091158),
#  ('styles', 0.78592891401091158),
#  ('frank', 0.78275933924963248),
#  ('matches', 0.78275933924963248),
#  ('tense', 0.78275933924963248),
#  ('backgrounds', 0.78275933924963248),
#  ('gothic', 0.78209466657644144),
#  ('sharp', 0.7814397877056235),
#  ('achieved', 0.78015855754957497),
#  ('court', 0.77947526404844247),
#  ('steals', 0.7789140023173704),
#  ('rules', 0.77844476107184035),
#  ('colors', 0.77684619943659217),
#  ('reunion', 0.77318988823348167),
#  ('covers', 0.77139937745969345),
#  ('tale', 0.77010822169607374),
#  ('rain', 0.7683706017975328),
#  ('denzel', 0.76804848873306297),
#  ('stays', 0.76787072675588186),
#  ('blob', 0.76725515271366718),
#  ('conventional', 0.76214005204689672),
#  ('maria', 0.76214005204689672),
#  ('fresh', 0.76158434211317383),
#  ('midnight', 0.76096977689870637),
#  ('landscape', 0.75852993982279704),
#  ('animated', 0.75768570169751648),
#  ('titanic', 0.75666058628227129),
#  ('sunday', 0.75666058628227129),
#  ('spring', 0.7537718023763802),
#  ('cagney', 0.7537718023763802),
#  ('enjoyable', 0.75246375771636476),
#  ('immensely', 0.75198768058287868),
#  ('sir', 0.7507762933965817),
#  ('nevertheless', 0.75067102469813185),
#  ('driven', 0.74994477895307854),
#  ('performances', 0.74883252516063137),
#  ('memories', 0.74721440183022114),
#  ('nowadays', 0.74721440183022114),
#  ('simple', 0.74641420974143258),
#  ('leslie', 0.74533293373051557),
#  ('golden', 0.74533293373051557),
#  ('lovers', 0.74497224842453125),
#  ('relationship', 0.74484232345601786),
#  ('supporting', 0.74357803418683721),
#  ('che', 0.74262723782331497),
#  ('packed', 0.7410032017375805),
#  ('trek', 0.74021469141793106),
#  ('provoking', 0.73840377214806618),
#  ('strikes', 0.73759894313077912),
#  ('depiction', 0.73682224406260699),
#  ('emotional', 0.73678211645681524),
#  ('secretary', 0.7366322924996842),
#  ('florida', 0.73511137965897755),
#  ('influenced', 0.73511137965897755),
#  ('germany', 0.73288750920945944),
#  ('brings', 0.73142936713096229),
#  ('lewis', 0.73129894652432159),
#  ('elderly', 0.73088750854279239),
#  ('owner', 0.72743625403857748),
#  ('streets', 0.72666987259858895),
#  ('henry', 0.72642196944481741),
#  ('portrays', 0.72593700338293632),
#  ('bears', 0.7252354951114458),
#  ('china', 0.72489587887452556),
#  ('anger', 0.72439972406404984),
#  ('society', 0.72433010799663333),
#  ('available', 0.72415741730250549),
#  ('best', 0.72347034060446314),
#  ('bugs', 0.72270598280148979),
#  ('magic', 0.71878961117328299),
#  ('verhoeven', 0.71846498854423513),
#  ('delivers', 0.71846498854423513),
#  ('jim', 0.71783979315031676),
#  ('donald', 0.71667767797013937),
#  ('endearing', 0.71465338578090898),
#  ('relationships', 0.71393795022901896),
#  ('greatly', 0.71256526641704687),
#  ('charlie', 0.71024161391924534),
#  ('brad', 0.71024161391924534),
#  ('simon', 0.70967648251115578),
#  ('effectively', 0.70914752190638641),
#  ('march', 0.70774597998109789),
#  ('atmosphere', 0.70744773070214162),
#  ('influence', 0.70733181555190172),
#  ('genius', 0.706392407309966),
#  ('emotionally', 0.70556970055850243),
#  ('ken', 0.70526854109229009),
#  ('identity', 0.70484322032313651),
#  ('sophisticated', 0.70470800296102132),
#  ('dan', 0.70457587638356811),
#  ('andrew', 0.70329955202396321),
#  ('india', 0.70144598337464037),
#  ('roy', 0.69970458110610434),
#  ('surprisingly', 0.6995780708902356),
#  ('sky', 0.69780919366575667),
#  ('romantic', 0.69664981111114743),
#  ('match', 0.69566924999265523),
#  ('britain', 0.69314718055994529),
#  ('affected', 0.69314718055994529),
#  ('meets', 0.69314718055994529),
#  ('bitter', 0.69314718055994529),
#  ('beatty', 0.69314718055994529),
#  ('stylish', 0.69314718055994529),
#  ('patient', 0.69314718055994529),
#  ('cowboy', 0.69314718055994529),
#  ('wave', 0.69314718055994529),
#  ('love', 0.69198533541937324),
#  ('paul', 0.68980827929443067),
#  ('andy', 0.68846333124751902),
#  ('performance', 0.68797386327972465),
#  ('patrick', 0.68645819240914863),
#  ('unlike', 0.68546468438792907),
#  ('brooks', 0.68433655087779044),
#  ('refuses', 0.68348526964820844),
#  ('complaint', 0.6824518914431974),
#  ('award', 0.6824518914431974),
#  ('ride', 0.68229716453587952),
#  ('dawson', 0.68171848473632257),
#  ('luke', 0.68158635815886937),
#  ('wells', 0.68087708796813096),
#  ('france', 0.6804081547825156),
#  ('sports', 0.68007509899259255),
#  ('handsome', 0.68007509899259255),
#  ('rebel', 0.67875844310784572),
#  ('directs', 0.67875844310784572),
#  ('greater', 0.67605274720064523),
#  ('dreams', 0.67599410133369586),
#  ('effective', 0.67565402311242806),
#  ('interpretation', 0.67479804189174875),
#  ('brando', 0.67445504754779284),
#  ('works', 0.67445504754779284),
#  ('noble', 0.6737290947028437),
#  ('paced', 0.67314651385327573),
#  ('le', 0.67067432470788668),
#  ('master', 0.67015766233524654),
#  ('h', 0.6696166831497512),
#  ('rings', 0.66904962898088483),
#  ('easy', 0.66895995494594152),
#  ('city', 0.66820823221269321),
#  ('sunshine', 0.66782937257565544),
#  ('succeeds', 0.66647893347778397),
#  ('relations', 0.664159643686693),
#  ('england', 0.66387679825983203),
#  ('glimpse', 0.66329421741026418),
#  ('aired', 0.66268797307523675),
#  ('sees', 0.66263163663399482),
#  ('both', 0.66248336767382998),
#  ('definitely', 0.66199789483898808),
#  ('imaginative', 0.66139848224536502),
#  ('appreciate', 0.66083893732728749),
#  ('tricks', 0.66071190480679143),
#  ('striking', 0.66071190480679143),
#  ('carefully', 0.65999497324304479),
#  ('complicated', 0.65981076029235353),
#  ('perspective', 0.65962448852130173),
#  ('trilogy', 0.65877953705573755),
#  ('future', 0.65834665141052828),
#  ('lion', 0.65742909795786608),
#  ('douglas', 0.65540685257709819),
#  ('victor', 0.65540685257709819),
#  ('inspired', 0.65459851044271034),
#  ('marriage', 0.65392646740666405),
#  ('demands', 0.65392646740666405),
#  ('father', 0.65172321672194655),
#  ('page', 0.65123628494430852),
#  ('instant', 0.65058756614114943),
#  ('era', 0.6495567444850836),
#  ('ruthless', 0.64934455790155243),
#  ('saga', 0.64934455790155243),
#  ('joan', 0.64891392558311978),
#  ('joseph', 0.64841128671855386),
#  ('workers', 0.64829661439459352),
#  ('fantasy', 0.64726757480925168),
#  ('distant', 0.64551913157069074),
#  ('accomplished', 0.64551913157069074),
#  ('manhattan', 0.64435701639051324),
#  ('personal', 0.64355023942057321),
#  ('individual', 0.64313675998528386),
#  ('meeting', 0.64313675998528386),
#  ('pushing', 0.64313675998528386),
#  ('pleasant', 0.64250344774119039),
#  ('brave', 0.64185388617239469),
#  ('william', 0.64083139119578469),
#  ('hudson', 0.64077919504262937),
#  ('friendly', 0.63949446706762514),
#  ('eccentric', 0.63907995928966954),
#  ('awards', 0.63875310849414646),
#  ('jack', 0.63838309514997038),
#  ('seeking', 0.63808740337691783),
#  ('divorce', 0.63757732940513456),
#  ('colonel', 0.63757732940513456),
#  ('jane', 0.63443957973316734),
#  ('keeping', 0.63414883979798953),
#  ('gives', 0.63383568159497883),
#  ('ted', 0.63342794585832296),
#  ('animation', 0.63208692379869902),
#  ('progress', 0.6317782341836532),
#  ('concert', 0.63127177684185776),
#  ('larger', 0.63127177684185776),
#  ('nation', 0.6296337748376194),
#  ('albeit', 0.62739580299716491),
#  ('adapted', 0.62613647027698516),
#  ('discovers', 0.62542900650499444),
#  ('classic', 0.62504956428050518),
#  ('segment', 0.62335141862440335),
#  ('morgan', 0.62303761437291871),
#  ('mouse', 0.62294292188669675),
#  ('impressive', 0.62211140744319349),
#  ('ultimate', 0.62168821657780038),
#  ('artist', 0.62168821657780038),
#  ('griffith', 0.62117368093485603),
#  ('emily', 0.62082651898031915),
#  ('drew', 0.62082651898031915),
#  ('moved', 0.6197197120051281),
#  ('families', 0.61903920840622351),
#  ('profound', 0.61903920840622351),
#  ('innocent', 0.61851219917136446),
#  ('versions', 0.61730910416844087),
#  ('eddie', 0.61691981517206107),
#  ('criticism', 0.61651395453902935),
#  ('nature', 0.61594514653194088),
#  ('recognized', 0.61518563909023349),
#  ('sexuality', 0.61467556511845012),
#  ('contract', 0.61400986000122149),
#  ('brian', 0.61344043794920278),
#  ('remembered', 0.6131044728864089),
#  ('determined', 0.6123858239154869),
#  ('offers', 0.61207935747116349),
#  ('pleasure', 0.61195702582993206),
#  ('washington', 0.61180154110599294),
#  ('images', 0.61159731359583758),
#  ('games', 0.61067095873570676),
#  ('academy', 0.60872983874736208),
#  ('fashioned', 0.60798937221963845),
#  ('melodrama', 0.60749173598145145),
#  ('charismatic', 0.60613580357031549),
#  ('peoples', 0.60613580357031549),
#  ('rough', 0.60613580357031549),
#  ('dealing', 0.60517840761398811),
#  ('fine', 0.60496962268013299),
#  ('tap', 0.60391604683200273),
#  ('trio', 0.60157998703445481),
#  ('russell', 0.60120968523425966),
#  ('figures', 0.60077386042893011),
#  ('ward', 0.60005675749393339),
#  ('shine', 0.59911823091166894),
#  ('brady', 0.59911823091166894),
#  ('job', 0.59845562125168661),
#  ('satisfied', 0.59652034487087369),
#  ('river', 0.59637962862495086),
#  ('brown', 0.595773016534769),
#  ('believable', 0.59566072133302495),
#  ('always', 0.59470710774669278),
#  ('bound', 0.59470710774669278),
#  ('hall', 0.5933967777928858),
#  ('cook', 0.5916777203950857),
#  ('claire', 0.59136448625000293),
#  ('broadway', 0.59033768669372433),
#  ('anna', 0.58778666490211906),
#  ('peace', 0.58628403501758408),
#  ('visually', 0.58539431926349916),
#  ('falk', 0.58525821854876026),
#  ('morality', 0.58525821854876026),
#  ('growing', 0.58466653756587539),
#  ('stood', 0.58314628534561685),
#  ('experiences', 0.58314628534561685),
#  ('touch', 0.58122926435596001),
#  ('lives', 0.5810976767513224),
#  ('kubrick', 0.58066919713325493),
#  ('timing', 0.58047401805583243),
#  ('expressions', 0.57981849525294216),
#  ('struggles', 0.57981849525294216),
#  ('authentic', 0.57848427223980559),
#  ('helen', 0.57763429343810091),
#  ('pre', 0.57700753064729182),
#  ('quirky', 0.5753641449035618),
#  ('young', 0.57531672344534313),
#  ('inner', 0.57454143815209846),
#  ('mexico', 0.57443087372056334),
#  ('clint', 0.57380042292737909),
#  ('sisters', 0.57286101468544337),
#  ('realism', 0.57226528899949558),
#  ('french', 0.5720692490067093),
#  ('personalities', 0.5720692490067093),
#  ('surprises', 0.57113222999698177),
#  ('adventures', 0.57113222999698177),
#  ('overcome', 0.5697681593994407),
#  ('timothy', 0.56953322459276867),
#  ('tales', 0.56909453188996639),
#  ('war', 0.56843317302781682),
#  ('civil', 0.5679840376059393),
#  ('countries', 0.56737779327091187),
#  ('streep', 0.56710645966458029),
#  ('tradition', 0.56685345523565323),
#  ('oliver', 0.56673325570428668),
#  ('australia', 0.56580775818334383),
#  ('understanding', 0.56531380905006046),
#  ('players', 0.56509525370004821),
#  ('knowing', 0.56489284503626647),
#  ('rogers', 0.56421349718405212),
#  ('suspenseful', 0.56368911332305849),
#  ('variety', 0.56368911332305849),
#  ('true', 0.56281525180810066),
#  ('jr', 0.56220982311246936),
#  ('psychological', 0.56108745854687891),
#  ('grand', 0.55961578793542266),
#  ('overwhelming', 0.55961578793542266),
#  ('performing', 0.55961578793542266),
#  ('branagh', 0.55961578793542266),
#  ('odds', 0.55961578793542266),
#  ('sent', 0.55961578793542266),
#  ('reminiscent', 0.55961578793542266),
#  ('wealth', 0.55961578793542266),
#  ('brothers', 0.55891181043362848),
#  ('howard', 0.55811089675600245),
#  ('david', 0.55693122256475369),
#  ('generation', 0.55628799784274796),
#  ('grow', 0.55612538299565417),
#  ('survival', 0.55594605904646033),
#  ('mainstream', 0.55574731115750231),
#  ('dick', 0.55431073570572953),
#  ('charm', 0.55288175575407861),
#  ('kirk', 0.55278982286502287),
#  ('twists', 0.55244729845681018),
#  ('gangster', 0.55206858230003986),
#  ('jeff', 0.55179306225421365),
#  ('family', 0.55116244510065526),
#  ('tend', 0.55053307336110335),
#  ('thanks', 0.55049088015842218),
#  ('world', 0.54744234723432639),
#  ('sutherland', 0.54743536937855164),
#  ('life', 0.54695514434959924),
#  ('disc', 0.54654370636806993),
#  ('bug', 0.54654370636806993),
#  ('tribute', 0.5455111817538808),
#  ('europe', 0.54522705048332309),
#  ('sacrifice', 0.54430155296238014),
#  ('color', 0.54405127139431109),
#  ('superior', 0.54333490233128523),
#  ('york', 0.54318235866536513),
#  ('pulls', 0.54266622962164945),
#  ('jackson', 0.54232429082536171),
#  ('hearts', 0.54232429082536171),
#  ('enjoy', 0.54124285135906114),
#  ('redemption', 0.54056759296472823),
#  ('madness', 0.540384426007535),
#  ('hamilton', 0.5389965007326869),
#  ('greek', 0.5389965007326869),
#  ('stands', 0.5389965007326869),
#  ('trial', 0.5389965007326869),
#  ('each', 0.5388212312554177),
#  ('faithful', 0.53773307668591508),
#  ('received', 0.5372768098531604),
#  ('jealous', 0.53714293208336406),
#  ('documentaries', 0.53714293208336406),
#  ('different', 0.53709860682460819),
#  ('describes', 0.53680111016925136),
#  ('shorts', 0.53596159703753288),
#  ('brilliance', 0.53551823635636209),
#  ('mountains', 0.53492317534505118),
#  ('dealt', 0.53408248593025787),
#  ('share', 0.53408248593025787),
#  ('explore', 0.53329847961804933),
#  ('providing', 0.53329847961804933),
#  ('series', 0.5325809226575603),
#  ('fellow', 0.5323318289869543),
#  ('olivier', 0.53062825106217038),
#  ('roman', 0.53062825106217038),
#  ('revolution', 0.53062825106217038),
#  ('loves', 0.53062825106217038),
#  ('century', 0.53002783074992665),
#  ('musical', 0.52966871156747064),
#  ('heroic', 0.52925932545482868),
#  ('ironically', 0.52806743020049673),
#  ('approach', 0.52806743020049673),
#  ('temple', 0.52806743020049673),
#  ('moves', 0.5279372642387119),
#  ('gift', 0.52702030968597136),
#  ('julie', 0.52609309589677911),
#  ('tells', 0.52415107836314001),
#  ('radio', 0.52394671172868779),
#  ('uncle', 0.52354439617376536),
#  ('union', 0.52324814376454787),
#  ('deep', 0.52309571635780505),
#  ('reminds', 0.52157841554225237),
#  ('famous', 0.52118841080153722),
#  ('jazz', 0.52053443789295151),
#  ('dennis', 0.51987545928590861),
#  ('epic', 0.51919387343650736),
#  ('adult', 0.519167695083386),
#  ('shows', 0.51915322220375304),
#  ('performed', 0.5191244265806858),
#  ('demons', 0.5191244265806858),
#  ('discovered', 0.51879379341516751),
#  ('eric', 0.51879379341516751),
#  ('youth', 0.5185626062681431),
#  ('human', 0.51851411224987087),
#  ('tarzan', 0.51813827061227724),
#  ('ourselves', 0.51794309153485463),
#  ('wwii', 0.51758240622887042),
#  ('passion', 0.5162164724008671),
#  ('desire', 0.51607497965213445),
#  ('pays', 0.51581316527702981),
#  ('dirty', 0.51557622652458857),
#  ('fox', 0.51557622652458857),
#  ('symbolism', 0.51546600332249293),
#  ('sympathetic', 0.51546600332249293),
#  ('attitude', 0.51530993621331933),
#  ('appearances', 0.51466440007315639),
#  ('jeremy', 0.51466440007315639),
#  ('fun', 0.51439068993048687),
#  ('south', 0.51420972175023116),
#  ('arrives', 0.51409894911095988),
#  ('present', 0.51341965894303732),
#  ('com', 0.51326167856387173),
#  ('smile', 0.51265880484765169),
#  ('visit', 0.51082562376599072),
#  ('fits', 0.51082562376599072),
#  ('alan', 0.51082562376599072),
#  ('ring', 0.51082562376599072),
#  ('carter', 0.51082562376599072),
#  ('aging', 0.51082562376599072),
#  ('provided', 0.51082562376599072),
#  ('countryside', 0.51082562376599072),
#  ('begins', 0.51015650363396647),
#  ('success', 0.50900578704900468),
#  ('japan', 0.50900578704900468),
#  ('accurate', 0.50895471583017893),
#  ('proud', 0.50800474742434931),
#  ('daily', 0.5075946031845443),
#  ('atmospheric', 0.50724780241810674),
#  ('karloff', 0.50724780241810674),
#  ('recently', 0.50714914903668207),
#  ('fu', 0.50704490092608467),
#  ('horrors', 0.50656122497953315),
#  ('finding', 0.50637127341661037),
#  ('lust', 0.5059356384717989),
#  ('hitchcock', 0.50574947073413001),
#  ('among', 0.50334004951332734),
#  ('viewing', 0.50302139827440906),
#  ('investigation', 0.50262885656181222),
#  ('shining', 0.50262885656181222),
#  ('duo', 0.5020919437972361),
#  ('cameron', 0.5020919437972361),
#  ('finds', 0.50128303100539795),
#  ('contemporary', 0.50077528791248915),
#  ('genuine', 0.50046283673044401),
#  ('frightening', 0.49995595152908684),
#  ('plays', 0.49975983848890226),
#  ('age', 0.49941323171424595),
#  ('position', 0.49899116611898781),
#  ('continues', 0.49863035067217237),
#  ('roles', 0.49839716550752178),
#  ('james', 0.49837216269470402),
#  ('individuals', 0.49824684155913052),
#  ('brought', 0.49783842823917956),
#  ('hilarious', 0.49714551986191058),
#  ('brutal', 0.49681488669639234),
#  ('appropriate', 0.49643688631389105),
#  ('dance', 0.49581998314812048),
#  ('helping', 0.49578774640145024),
#  ('league', 0.49578774640145024),
#  ('answers', 0.49578774640145024),
#  ('stunts', 0.49561620510246196),
#  ('traveling', 0.49532143723002542),
#  ('thoroughly', 0.49414593456733524),
#  ('depicted', 0.49317068852726992),
#  ('combination', 0.49247648509779424),
#  ('honor', 0.49247648509779424),
#  ('differences', 0.49247648509779424),
#  ('fully', 0.49213349075383811),
#  ('tracy', 0.49159426183810306),
#  ('battles', 0.49140753790888908),
#  ('possibility', 0.49112055268665822),
#  ('romance', 0.4901589869574316),
#  ('initially', 0.49002249613622745),
#  ('happy', 0.4898997500608791),
#  ('crime', 0.48977221456815834),
#  ('singing', 0.4893852925281213),
#  ('especially', 0.48901267837860624),
#  ('shakespeare', 0.48754793889664511),
#  ('hugh', 0.48729512635579658),
#  ('detail', 0.48609484250827351),
#  ('san', 0.48550781578170082),
#  ('companion', 0.48550781578170082),
#  ('desperation', 0.48550781578170082),
#  ('julia', 0.48550781578170082),
#  ('guide', 0.48550781578170082),
#  ('strongly', 0.48460242866688824),
#  ('necessary', 0.48302334245403883),
#  ('humanity', 0.48265474679929443),
#  ('drama', 0.48221998493060503),
#  ('cuba', 0.48183808689273838),
#  ('warming', 0.48183808689273838),
#  ('intrigue', 0.48183808689273838),
#  ('nonetheless', 0.48183808689273838),
#  ('planned', 0.47957308026188628),
#  ('pictures', 0.47929937011921681),
#  ('broadcast', 0.47849024312305422),
#  ('nine', 0.47803580094299974),
#  ('settings', 0.47743860773325364),
#  ('history', 0.47732966933780852),
#  ('ordinary', 0.47725880012690741),
#  ('trade', 0.47692407209030935),
#  ('official', 0.47608267532211779),
#  ('primary', 0.47608267532211779),
#  ('episode', 0.47529620261150429),
#  ('role', 0.47520268270188676),
#  ('spirit', 0.47477690799839323),
#  ('grey', 0.47409361449726067),
#  ('ways', 0.47323464982718205),
#  ('piano', 0.47260441094579297),
#  ('cup', 0.47260441094579297),
#  ('familiar', 0.47241617565111949),
#  ('sinister', 0.47198579044972683),
#  ('reveal', 0.47171449364936496),
#  ('max', 0.47150852042515579),
#  ('dated', 0.47121648567094482),
#  ('discovery', 0.47000362924573563),
#  ('vicious', 0.47000362924573563),
#  ('losing', 0.47000362924573563),
#  ('genuinely', 0.46871413841586385),
#  ('hatred', 0.46734051182625186),
#  ('mistaken', 0.46702300110759781),
#  ('challenge', 0.46608972992459924),
#  ('dream', 0.46608972992459924),
#  ('crisis', 0.46575733836428446),
#  ('photographed', 0.46488852857896512),
#  ('critics', 0.46430560813109778),
#  ('bird', 0.46430560813109778),
#  ('machines', 0.46430560813109778),
#  ('born', 0.46411383518967209),
#  ('detective', 0.4636633473511525),
#  ('higher', 0.46328467899699055),
#  ('remains', 0.46262352194811296),
#  ('inevitable', 0.46262352194811296),
#  ('soviet', 0.4618180446592961),
#  ('ryan', 0.46134556650262099),
#  ('african', 0.46112595521371813),
#  ('smaller', 0.46081520319132935),
#  ('techniques', 0.46052488529119184),
#  ('information', 0.46034171833399862),
#  ('deserved', 0.45999798712841444),
#  ('cynical', 0.45953232937844013),
#  ('spielberg', 0.45953232937844013),
#  ('tour', 0.45953232937844013),
#  ('francisco', 0.45953232937844013),
#  ('lynch', 0.45953232937844013),
#  ('struggle', 0.45911782160048453),
#  ('language', 0.45902121257712653),
#  ('visual', 0.45823514408822852),
#  ('warner', 0.45724137763188427),
#  ('social', 0.45720078250735313),
#  ('reality', 0.45719346885019546),
#  ('hidden', 0.45675840249571492),
#  ('breaking', 0.45601738727099561),
#  ('sometimes', 0.45563021171182794),
#  ('modern', 0.45500247579345005),
#  ('surfing', 0.45425527227759638),
#  ('popular', 0.45410691533051023),
#  ('surprised', 0.4534409399850382),
#  ('follows', 0.45245361754408348),
#  ('keeps', 0.45234869400701483),
#  ('john', 0.4520909494482197),
#  ('defeat', 0.45198512374305722),
#  ('mixed', 0.45198512374305722),
#  ('justice', 0.45142724367280018),
#  ('treasure', 0.45083371313801535),
#  ('presents', 0.44973793178615257),
#  ('years', 0.44919197032104968),
#  ('chief', 0.44895022004790319),
#  ('shadows', 0.44802472252696035),
#  ('closely', 0.44701411102103689),
#  ('segments', 0.44701411102103689),
#  ('lose', 0.44658335503763702),
#  ('caine', 0.44628710262841953),
#  ('caught', 0.44610275383999071),
#  ('hamlet', 0.44558510189758965),
#  ('chinese', 0.44507424620321018),
#  ('welcome', 0.44438052435783792),
#  ('birth', 0.44368632092836219),
#  ('represents', 0.44320543609101143),
#  ('puts', 0.44279106572085081),
#  ('fame', 0.44183275227903923),
#  ('closer', 0.44183275227903923),
#  ('web', 0.44183275227903923),
#  ('visuals', 0.44183275227903923),
#  ('criminal', 0.4412745608048752),
#  ('minor', 0.4409224199448939),
#  ('jon', 0.44086703515908027),
#  ('liked', 0.44074991514020723),
#  ('restaurant', 0.44031183943833246),
#  ('flaws', 0.43983275161237217),
#  ('de', 0.43983275161237217),
#  ('searching', 0.4393666597838457),
#  ('rap', 0.43891304217570443),
#  ('light', 0.43884433018199892),
#  ('elizabeth', 0.43872232986464682),
#  ('marry', 0.43861731542506488),
#  ('learned', 0.43825493093115531),
#  ('controversial', 0.43825493093115531),
#  ('oz', 0.43825493093115531),
#  ('slowly', 0.43785660389939979),
#  ('thrilling', 0.43721380642274466),
#  ('wayne', 0.43721380642274466),
#  ('comedic', 0.43721380642274466),
#  ('bridge', 0.43721380642274466),
#  ('married', 0.43658501682196887),
#  ('nazi', 0.4361020775700542),
#  ('murder', 0.4353180712578455),
#  ('physical', 0.4353180712578455),
#  ('johnny', 0.43483971678806865),
#  ('michelle', 0.43445264498141672),
#  ('wallace', 0.43403848055222038),
#  ('silent', 0.43395706390247063),
#  ('comedies', 0.43395706390247063),
#  ('played', 0.43387244114515305),
#  ('international', 0.43363598507486073),
#  ('vision', 0.43286408229627887),
#  ('intelligent', 0.43196704885367099),
#  ('shop', 0.43078291609245434),
#  ('also', 0.43036720209769169),
#  ('levels', 0.4302451371066513),
#  ('miss', 0.43006426712153217),
#  ('enormous', 0.4295626596872249),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('boll', -4.0778152602708904),
#  ('uwe', -3.9218753018711578),
#  ('seagal', -3.3202501058581921),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.7753833211707968),
#  ('incoherent', -2.7641396677532537),
#  ('unfunny', -2.5545257844967644),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('horrid', -2.3715779644809971),
#  ('pointless', -2.3451073877136341),
#  ('atrocious', -2.3187369339642556),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('drivel', -2.2476029585766928),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.1326133844207011),
#  ('wasting', -2.1178155545614512),
#  ('remotely', -2.111046881095167),
#  ('existent', -2.0024805005437076),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.9216610938019989),
#  ('sucks', -1.9166645809588516),
#  ('uninspired', -1.9131499212248517),
#  ('lame', -1.9117232884159072),
#  ('insult', -1.9085323769376259)]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bf9c50f9-c5af-4152-ba2d-427b745295bd">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3bdd3f05-5312-4c32-8374-82215f839f28"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3bdd3f05-5312-4c32-8374-82215f839f28").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3bdd3f05-5312-4c32-8374-82215f839f28");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3bdd3f05-5312-4c32-8374-82215f839f28' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"55cc86b4-5a09-44b5-8d29-60c067403429":{"roots":{"references":[{"attributes":{},"id":"251e50bc-1c13-40f2-8ba0-d2c6d4229056","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"a9073d66-1c1e-4afd-9b92-327a6375dcc1","subtype":"Figure","type":"Plot"},"ticker":{"id":"935fb9e1-cd40-4b97-845f-7bdfd179bdf9","type":"BasicTicker"}},"id":"2c9c1b34-1579-49d0-b35b-d8ad1bcffb6e","type":"Grid"},{"attributes":{"plot":{"id":"a9073d66-1c1e-4afd-9b92-327a6375dcc1","subtype":"Figure","type":"Plot"}},"id":"34d4fe93-51cb-4938-94a4-e5d21ae804f4","type":"WheelZoomTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":
type":"GlyphRenderer"},{"attributes":{"below":[{"id":"8fb53999-5bfc-432e-81fc-8492745519d1","type":"LinearAxis"}],"left":[{"id":"28c7d93a-bea3-4377-a236-04c2312ec692","type":"LinearAxis"}],"renderers":[{"id":"8fb53999-5bfc-432e-81fc-8492745519d1","type":"LinearAxis"},{"id":"53960715-e863-492c-ab75-e7920d05125a","type":"Grid"},{"id":"28c7d93a-bea3-4377-a236-04c2312ec692","type":"LinearAxis"},{"id":"e969db65-65e6-4fe6-88ff-265b26485209","type":"Grid"},{"id":"5a7d8b3d-5d9f-4ca8-bcf9-86e9a870dfee","type":"GlyphRenderer"}],"title":{"id":"97219839-a87b-4e50-a35b-f06835597789","type":"Title"},"tool_events":{"id":"4fadd370-5355-49f7-bb06-9d7b3dbefa17","type":"ToolEvents"},"toolbar":{"id":"ac190d70-5465-4654-8992-b45cd248a0d0","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"e82adbfa-239d-470e-9ca6-b51e55ed3849","type":"DataRange1d"},"y_range":{"id":"620de064-d9dc-4b60-937a-d772a145880b","type":"DataRange1d"}},"id":"0e75cfce-41b0-4359-a6eb-69e5fbbc71fb","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"b38b2165-364e-45d0-b6d6-f2300692a419","type":"Quad"},{"attributes":{"plot":{"id":"0e75cfce-41b0-4359-a6eb-69e5fbbc71fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e3b66db-3829-4c33-872b-17956668261e","type":"BasicTicker"}},"id":"53960715-e863-492c-ab75-e7920d05125a","type":"Grid"},{"attributes":{"plot":null,"text":"The frequency distribution of the words in our corpus"},"id":"97219839-a87b-4e50-a35b-f06835597789","type":"Title"},{"attributes":{"plot":{"id":"0e75cfce-41b0-4359-a6eb-69e5fbbc7 ...

# %% [markdown]
# ## Reducing Noise by Strategically Reducing the Vocabulary

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork_4:
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
       
        np.random.seed(1)
    
        self.pre_process_data(reviews, polarity_cutoff, min_count)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self,reviews, polarity_cutoff,min_count):
        
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'positive'):
                for word in reviews[i].split(" "):
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i].split(" "):
                    negative_counts[word] += 1
                    total_counts[word] += 1

        pos_neg_ratios = Counter()

        for term,cnt in list(total_counts.most_common()):
            if(cnt >= 50):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio

        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
        self.layer_1 = np.zeros((1,hidden_nodes))
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            self.layer_0[0][self.word2index[word]] = 1

    def get_target_for_label(self,label):
        if(label == 'positive'):
            return 1
        else:
            return 0
        
    def train(self, training_reviews_raw, training_labels):
        
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer

            # Hidden layer
#             layer_1 = self.layer_0.dot(self.weights_0_1)
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]
            
            # Output layer
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(layer_2 >= 0.5 and label == 'positive'):
                correct_so_far += 1
            if(layer_2 < 0.5 and label == 'negative'):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
        
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer


        # Hidden layer
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] >= 0.5):
            return "positive"
        else:
            return "negative"

# %%
mlp = SentimentNetwork_4(reviews_clean[:-1000],labels_clean[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)

# %%
mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):532.0 #Correct:20327 #Trained:24000 Training Accuracy:84.6%

# %%
mlp.test(reviews_clean[-1000:],labels_clean[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):878.4% #Correct:859 #Tested:1000 Testing Accuracy:85.9%

# %%
mlp = SentimentNetwork_4(reviews_clean[:-1000],labels_clean[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)

# %%
mlp.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):623.7 #Correct:20327 #Trained:24000 Training Accuracy:84.6%

# %%
mlp.test(reviews_clean[-1000:],labels_clean[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):881.1% #Correct:859 #Tested:1000 Testing Accuracy:85.9%

# %% [markdown]
# ## What's going on in the weight

# %%
mlp_full = SentimentNetwork_4(reviews_clean[:-1000],labels_clean[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews_clean[:-1000],labels_clean[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):704.0 #Correct:20335 #Trained:24000 Training Accuracy:84.7%

# %%
def get_most_similar_words(focus = "excellent"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")
# Out:
# [('excellent', 0.13672950757352473),
#  ('perfect', 0.12548286087225946),
#  ('amazing', 0.091827633925999713),
#  ('today', 0.090223662694414244),
#  ('wonderful', 0.089355976962214631),
#  ('fun', 0.087504466674206915),
#  ('great', 0.087141758882292059),
#  ('best', 0.085810885617880583),
#  ('liked', 0.077697629123843454),
#  ('definitely', 0.076628781406966037),
#  ('brilliant', 0.073423858769279066),
#  ('loved', 0.073285428928122176),
#  ('favorite', 0.072781136036160779),
#  ('superb', 0.071736207178505096),
#  ('fantastic', 0.070922191916266211),
#  ('job', 0.06916061720763407),
#  ('incredible', 0.066424077952614416),
#  ('enjoyable', 0.06563256050288882),
#  ('rare', 0.064819212662615089),
#  ('highly', 0.063889453350970557),
#  ('enjoyed', 0.062127546101812973),
#  ('wonderfully', 0.062055178604090176),
#  ('perfectly', 0.061093208811887373),
#  ('fascinating', 0.0606635479374939),
#  ('bit', 0.05965542704565302),
#  ('gem', 0.059510859296156786),
#  ('outstanding', 0.058860808147083027),
#  ('beautiful', 0.058613934703162077),
#  ('surprised', 0.05827331448256301),
#  ('worth', 0.057657484236471213),
#  ('especially', 0.057422020781760806),
#  ('refreshing', 0.057310532092265769),
#  ('entertaining', 0.056612033835629252),
#  ('hilarious', 0.056168541032286655),
#  ('masterpiece', 0.054993988649431579),
#  ('simple', 0.054484083134924109),
#  ('subtle', 0.054368883033508633),
#  ('funniest', 0.053457164871302698),
#  ('solid', 0.052903564743620665),
#  ('awesome', 0.052489194202770421),
#  ('always', 0.052260328525345276),
#  ('noir', 0.051530194726406894),
#  ('guys', 0.051109413645642705),
#  ('sweet', 0.050818930317526004),
#  ('unique', 0.050670162263589197),
#  ('very', 0.050132994948528492),
#  ('heart', 0.049948058498243623),
#  ('moving', 0.049424601164379141),
#  ('atmosphere', 0.048842500895912876),
#  ('strong', 0.048570880631759225),
#  ('remember', 0.04847903694229129),
#  ('believable', 0.048415384391603804),
#  ('pleasant', 0.013180077348723351),
#  ('horses', 0.013178651568029474),
#  ('about', 0.01316615452800686),
#  ('astounding', 0.013161698337226814),
#  ('savage', 0.01315410055375993),
#  ('winning', 0.013153246708379664),
#  ('rose', 0.013145586701309784),
#  ('fitting', 0.013133578254330345),
#  ('compared', 0.013131693803520044),
#  ('took', 0.013119343481499001),
#  ('masterson', 0.013112762074217887),
#  ('owner', 0.013108690454819149),
#  ('delight', 0.013107278788311015),
#  ('conventions', 0.013106039770696047),
#  ('natali', 0.01309496444114322),
#  ('message', 0.013093664295113432),
#  ('stood', 0.013090122718303438),
#  ('sailor', 0.013058959170423455),
#  ('ida', 0.013058842950256241),
#  ('escaping', 0.013052723624706783),
#  ('top', 0.013047466741024413),
#  ('louis', 0.013046238442637021),
#  ('peace', 0.013040907918892317),
#  ('several', 0.013028244887060308),
#  ('info', 0.013023754625550187),
#  ('graphics', 0.013020850288881858),
#  ('reflection', 0.013019243823940105),
#  ('slimy', 0.013014377070231847),
#  ('elvira', 0.013009811638957067),
#  ('andre', 0.013000047313446747),
#  ('kong', 0.012999080313300514),
#  ('mayor', 0.012994758409723568),
#  ('punishment', 0.012988264949614949),
#  ('morris', 0.012983710119604969),
#  ('hall', 0.012981593609354818),
#  ('match', 0.012980233583057331),
#  ('bleak', 0.012972505086304069),
#  ('lindy', 0.012972248933121265),
#  ('sequence', 0.01296443580871358),
#  ('learn', 0.012938848970083341),
#  ('happen', 0.012932836387873745),
#  ('john', 0.012929524979001678),
#  ('gothic', 0.012926957011734876),
#  ('wider', 0.012920985981480958),
#  ('popular', 0.012891690509844083),
#  ('diverse', 0.012875263936567818),
#  ('compare', 0.012869395292065211),
#  ('brooklyn', 0.012852986243263932),
#  ('broadcast', 0.012839574692097627),
#  ('zane', 0.012834302957709137),
#  ('andrew', 0.012824020940615256),
#  ('finely', 0.01282271600401586),
#  ('confronted', 0.012817523686608635),
#  ('going', 0.012809762839304975),
#  ('likewise', 0.012804639349082519),
#  ('breath', 0.012790132659417901),
#  ('building', 0.012789809704793874),
#  ('suggesting', 0.012780624321169349),
#  ('contemporary', 0.012772749462937525),
#  ('midnight', 0.012766963563112079),
#  ('victoria', 0.012756422131580533),
#  ('lasting', 0.012752424415642592),
#  ('kitty', 0.012751468371946009),
#  ('continued', 0.012744325456485404),
#  ('indian', 0.012712962842718691),
#  ('subplots', 0.012709887814283909),
#  ('douglas', 0.01269383067945591),
#  ('explosions', 0.012692697593201853),
#  ('bond', 0.012689802823687828),
#  ('delightfully', 0.012669417460922625),
#  ('understated', 0.012669374312789356),
#  ('greater', 0.012664580396020166),
#  ('sailing', 0.01266242458128243),
#  ('images', 0.012661803048859881),
#  ('copy', 0.012624649645734178),
#  ('seat', 0.012610464273152509),
#  ('eleven', 0.012602533659978892),
#  ('riveting', 0.012591829460094513),
#  ('boiled', 0.012588863529638762),
#  ('academy', 0.01258199617814299),
#  ('whilst', 0.012569841653295643),
#  ('heaven', 0.012547361621330935),
#  ('fruit', 0.012543513029693254),
#  ('reviewer', 0.012534273375083898),
#  ('cost', 0.012529643005796613),
#  ('week', 0.012522845015008274),
#  ('intriguing', 0.012508687653306351),
#  ('streak', 0.012507752385208556),
#  ('san', 0.012502130058217931),
#  ('awareness', 0.012476446442012455),
#  ('catching', 0.012467108595451542),
#  ('kicks', 0.012457714930570588),
#  ('complexities', 0.012454362663082469),
#  ('draws', 0.01244775328512591),
#  ('easily', 0.012444885855614905),
#  ('ealing', 0.01244433925570893),
#  ('psychopath', 0.012431259926282275),
#  ('skin', 0.01242424854097357),
#  ('creative', 0.012386713452491526),
#  ('recognition', 0.012354025801439425),
#  ('downey', 0.012348698765161134),
#  ('symbolism', 0.012329925038271331),
#  ('touches', 0.01232801347075147),
#  ('everyday', 0.012324934809895898),
#  ('achieves', 0.012314898707483498),
#  ('outcast', 0.012313662230219676),
#  ('overwhelmed', 0.012306633138869481),
#  ...]

# %%
get_most_similar_words("terrible")
# Out:
# [('worst', 0.16966107259049845),
#  ('awful', 0.12026847019691243),
#  ('waste', 0.11945367265311005),
#  ('poor', 0.092758887574435511),
#  ('terrible', 0.091425387197727956),
#  ('dull', 0.084209271678223618),
#  ('poorly', 0.081241544516042041),
#  ('disappointment', 0.080064759621368733),
#  ('fails', 0.078599773723337527),
#  ('disappointing', 0.07733948548032335),
#  ('boring', 0.077127858748012881),
#  ('unfortunately', 0.075502449705859079),
#  ('worse', 0.070601835364194662),
#  ('mess', 0.070564299623590412),
#  ('stupid', 0.06948482283254305),
#  ('badly', 0.066888903666228544),
#  ('annoying', 0.065687021903374165),
#  ('bad', 0.063093814537572152),
#  ('save', 0.062880597495865762),
#  ('disappointed', 0.062692353812072873),
#  ('wasted', 0.061387183028051275),
#  ('supposed', 0.060985452957725172),
#  ('horrible', 0.060121772339380125),
#  ('laughable', 0.058698406285467616),
#  ('crap', 0.05810452866788457),
#  ('basically', 0.057218840369636169),
#  ('nothing', 0.057158220043034204),
#  ('ridiculous', 0.056905481068931431),
#  ('lacks', 0.055766565889465443),
#  ('lame', 0.05561600905811017),
#  ('avoid', 0.055518726073197217),
#  ('unless', 0.054208926212940753),
#  ('script', 0.053948359467048478),
#  ('failed', 0.053413930550009141),
#  ('pointless', 0.052855531546894118),
#  ('oh', 0.052761580933176823),
#  ('effort', 0.050773747127292324),
#  ('guess', 0.050379576420076538),
#  ('minutes', 0.049784532804242179),
#  ('wooden', 0.049453108380727209),
#  ('redeeming', 0.04918286911472175),
#  ('seems', 0.049079625154669772),
#  ('instead', 0.047957645123532275),
#  ('weak', 0.046496387374765656),
#  ('pathetic', 0.04609974114971576),
#  ('looks', 0.045796536730244863),
#  ('hoping', 0.045082242887577027),
#  ('wonder', 0.044669791780934595),
#  ('forgettable', 0.042854349251871718),
#  ('silly', 0.042237829687270016),
#  ('attempt', 0.04170629994137353),
#  ('predictable', 0.041514442438568125),
#  ('someone', 0.041506119027337307),
#  ('sorry', 0.040868877281533364),
#  ('might', 0.040445683500688355),
#  ('slow', 0.040346869107034958),
#  ('painful', 0.040220039039613263),
#  ('thin', 0.040062642253777862),
#  ('mediocre', 0.03940716537757738),
#  ('garbage', 0.039310979440981109),
#  ('embarrassment', 0.013269530319198223),
#  ('regarding', 0.013233250211631653),
#  ('stilted', 0.013215539220141915),
#  ('sleeve', 0.013215085161586728),
#  ('rating', 0.013203442200940893),
#  ('kills', 0.013183919467358744),
#  ('sounds', 0.013178727878711733),
#  ('ali', 0.013173031266866371),
#  ('non', 0.013162603751805241),
#  ('pie', 0.013161492629253852),
#  ('populated', 0.013152746747459266),
#  ('killing', 0.013111860853151806),
#  ('else', 0.013110592541316694),
#  ('schneider', 0.013093514941690403),
#  ('priest', 0.013071537555948204),
#  ('hollow', 0.013068001463175459),
#  ('shower', 0.013029604174841071),
#  ('ruins', 0.013021597567104505),
#  ('mental', 0.013019696244479821),
#  ('this', 0.013009778169664525),
#  ('pregnant', 0.012997074834619551),
#  ('make', 0.012992851916498639),
#  ('timberlake', 0.012979689860020452),
#  ('saves', 0.012915795355367861),
#  ('vastly', 0.012914828969565761),
#  ('swear', 0.01290105947549007),
#  ('stella', 0.012883911119651207),
#  ('grave', 0.01288255504027714),
#  ('thats', 0.01286106181291034),
#  ('drinking', 0.012860129471019709),
#  ('boom', 0.012851779594694187),
#  ('introduction', 0.012831129197335466),
#  ('programming', 0.012796219757750258),
#  ('career', 0.012773059501084115),
#  ('stereotype', 0.012769447626661478),
#  ('attractive', 0.012765873120010145),
#  ('victims', 0.012749299245502162),
#  ('pass', 0.012735021821089281),
#  ('experiment', 0.012716112941788909),
#  ('retarded', 0.012713099529852416),
#  ('stuck', 0.012709332698253254),
#  ('akshay', 0.012684273069877868),
#  ('cut', 0.012676285239015489),
#  ('shoddy', 0.012674792040888049),
#  ('damme', 0.01266653641765667),
#  ('inaccurate', 0.01265368757753655),
#  ('ray', 0.012649818023510182),
#  ('woman', 0.012646521945546316),
#  ('research', 0.012640494662864559),
#  ('mile', 0.012627245693716737),
#  ('place', 0.012624645831509409),
#  ('demon', 0.012621688470792609),
#  ('vulgar', 0.012612150302693323),
#  ('engage', 0.012602272831074856),
#  ('wives', 0.012601890190118306),
#  ('mention', 0.012581598480006461),
#  ('if', 0.0125696312622347),
#  ('cartoon', 0.012561864177985762),
#  ('unbelievably', 0.012550391668315846),
#  ('only', 0.012517107727859144),
#  ('ended', 0.012507282716729795),
#  ('stereotypical', 0.012506426536204355),
#  ('spent', 0.012503032775055231),
#  ('thing', 0.012483110991541419),
#  ('phone', 0.012464039991489135),
#  ('stock', 0.012446742147556616),
#  ('drop', 0.012432978683590468),
#  ('self', 0.012432059211520794),
#  ('headache', 0.012424495134195471),
#  ('escapes', 0.012419211298248932),
#  ('conceived', 0.012392639977060705),
#  ('required', 0.012392260947042839),
#  ('assassin', 0.012332404091910099),
#  ('meat', 0.012327751187890429),
#  ('therefore', 0.012316138729629608),
#  ('struggling', 0.0123086283535723),
#  ('ho', 0.012307714936265705),
#  ('ta', 0.012299409649320241),
#  ('cold', 0.012289510775209279),
#  ('expects', 0.012271684887263186),
#  ('furthermore', 0.012263298696316205),
#  ('remote', 0.012254529263879219),
#  ('cgi', 0.012250569964074186),
#  ('porno', 0.0093907201413965125),
#  ('somehow', 0.0093889261270860575),
#  ('sarcasm', 0.0093886064393904119),
#  ('tie', 0.0093856009366311607),
#  ('fall', 0.0093801640008931274),
#  ('bring', 0.0093791273545761507),
#  ('rape', 0.0093760851230746366),
#  ('village', 0.0093684513318613993),
#  ('kitchen', 0.0093649071460109538),
#  ('concerned', 0.0093611353238811281),
#  ('republic', 0.0093499426948764255),
#  ('hell', 0.0093400360705317154),
#  ('inducing', 0.0093382129792553559),
#  ('stomach', 0.0093378286385158576),
#  ('shambles', 0.0093335457329829803),
#  ('virgin', 0.009331200133905598),
#  ('extraneous', 0.009325041380035131),
#  ('cameras', 0.0093229460267977224),
#  ('suffers', 0.0093204929924829982),
#  ('justified', 0.0093163217479363177),
#  ('plummer', 0.0092948273285103928),
#  ('ponderous', 0.009288034423722339),
#  ('player', 0.0092802296345443624),
#  ('survivor', 0.0092767026472125712),
#  ('rainy', 0.0092697034218137495),
#  ('graces', 0.0092620944963291325),
#  ...]

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize))

p.scatter(x="x1", y="x2", size=8, source=source,color=colors_list)

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
# Out:
# /home/isaac/anaconda3/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /home/isaac/anaconda3/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b2950be8-35c4-4e36-9d5f-3830efa56d9f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b2950be8-35c4-4e36-9d5f-3830efa56d9f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b2950be8-35c4-4e36-9d5f-3830efa56d9f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b2950be8-35c4-4e36-9d5f-3830efa56d9f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ef3e49a6-8c3d-4447-b34a-6ec3d0be81ac":{"roots":{"references":[{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"946ecf3f-e833-43ee-9c37-bd862739bcbe","type":"Circle"},{"attributes":{},"id":"3e1d4ded-94a8-4c60-813c-714d01e41bc5","type":"BasicTickFormatter"},{"attributes":{},"id":"b28d4627-edb4-4a30-ad64-f6125ac8a256","type":"BasicTicker"},{"attributes":{"plot":{"id":"27136e5d-9c5d-4752-97a3-87b75f6e67fa","subtype":"Figure","type":"Plot"}},"id":"16b677b9-9665-4694-a318-207435e5d830","type":"SaveTool"},{"attributes":{"formatter":{"id":"45558a0c-9589-4dae-bcce-d057990fd0a1","type":"BasicTickFormatter"},"plot":{"id":"27136e5d-9c5d-4752-97a3-87b75f6e67fa","subtype":"Figure","type":"Plot"},"ticker":{"id":"b28d4627-edb4-4a30-ad64-f6125ac8a256","type":"BasicTicker"}},"id":"c6fc4a77-b412-489e-92f9-a6ca55f2eeb7","type":"LinearAxis"},{"attributes":{},"id":"45558a0c-9589-4dae-bcce-d057990fd0a1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"27136e5d-9c5d-4752-97a3-87b75f6e67fa","subtype":"Figure","type":"Plot"}},"id":"601ccce3-28db-40bb-ac40-35a0c9ec11a0","type":"ResetTool"},{"attributes":{"plot":{"id":"27136e5d-9c5d-4752-97a3-87b75f6e67fa","subtype":"Figure","type":"Plot"}},"id":"ba6badc3-ee77-4cd7-952a-2a700935186c","type":"PanTool"},{"attributes":{},"id":"e652bf95-ea8d-469d-bb78-a0dbfe6c027e","type":"BasicTicker"},{"attributes":{},"id":"f37e0703-412c-4d8e-9f8d-8dbd54f45895","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x2","x1","names","fill_color","line_color"],"data":{"fill_color":["#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00","#00ff00" ...
